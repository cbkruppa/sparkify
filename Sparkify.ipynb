# %% [markdown]
# # Sparkify Project Workspace
# This workspace contains a tiny subset (128MB) of the full dataset available (12GB). Feel free to use this workspace to build your project, or to explore a smaller subset with Spark before deploying your cluster on the cloud. Instructions for setting up your Spark cluster is included in the last lesson of the Extracurricular Spark Course content.
#
# You can follow the steps below to guide your data analysis and model building portion of this project.

# %%
# import libraries
import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col, desc, asc
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import VectorAssembler, Normalizer, StandardScaler

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
# create a Spark session
spark = SparkSession \
    .builder \
    .appName("Sparkify Capstone Project for Udacity") \
    .getOrCreate()

# %%
# view Spark session configuration
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.app.id', 'local-1639875925745'),
#  ('spark.app.name', 'Sparkify Capstone Project for Udacity'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.master', 'local[*]'),
#  ('spark.executor.id', 'driver'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.driver.host', '5525b8ada7c4'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.driver.port', '37437')]

# %% [markdown]
# # Load and Clean Dataset
# In this workspace, the mini-dataset file is `mini_sparkify_event_data.json`. Load and clean the dataset, checking for invalid or missing data - for example, records without userids or sessionids.

# %%
# load in dataset
user_log = spark.read.json("mini_sparkify_event_data.json")

# %%
# view the schema
user_log.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
# view some row values
user_log.take(2)
# Out:
# [Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30'),
#  Row(artist='Five Iron Frenzy', auth='Logged In', firstName='Micah', gender='M', itemInSession=79, lastName='Long', length=236.09424, level='free', location='Boston-Cambridge-Newton, MA-NH', method='PUT', page='NextSong', registration=1538331630000, sessionId=8, song='Canada', status=200, ts=1538352180000, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"', userId='9')]

# %%
# view list of all possible pages
user_log.select("page").dropDuplicates().sort("page").collect()
# Out:
# [Row(page='About'),
#  Row(page='Add Friend'),
#  Row(page='Add to Playlist'),
#  Row(page='Cancel'),
#  Row(page='Cancellation Confirmation'),
#  Row(page='Downgrade'),
#  Row(page='Error'),
#  Row(page='Help'),
#  Row(page='Home'),
#  Row(page='Login'),
#  Row(page='Logout'),
#  Row(page='NextSong'),
#  Row(page='Register'),
#  Row(page='Roll Advert'),
#  Row(page='Save Settings'),
#  Row(page='Settings'),
#  Row(page='Submit Downgrade'),
#  Row(page='Submit Registration'),
#  Row(page='Submit Upgrade'),
#  Row(page='Thumbs Down'),
#  Row(page='Thumbs Up'),
#  Row(page='Upgrade')]

# %%
# view example of a user's chronological actions
user_log.select(["ts", "page", "song"]).where(user_log.userId == "30").orderBy(asc("ts")).collect()
# Out:
# [Row(ts=1538352117000, page='NextSong', song='Rockpools'),
#  Row(ts=1538352394000, page='NextSong', song='Time For Miracles'),
#  Row(ts=1538352676000, page='NextSong', song='Harder Better Faster Stronger'),
#  Row(ts=1538352899000, page='NextSong', song='Passengers (Old Album Version)'),
#  Row(ts=1538352905000, page='Add to Playlist', song=None),
#  Row(ts=1538353084000, page='NextSong', song='Fuck Kitty'),
#  Row(ts=1538353218000, page='NextSong', song='Jade'),
#  Row(ts=1538353441000, page='NextSong', song='So-Called Friends'),
#  Row(ts=1538353687000, page='NextSong', song='Represent'),
#  Row(ts=1538353909000, page='NextSong', song='Here I Am'),
#  Row(ts=1538354132000, page='NextSong', song='Rebirthing (Album Version)'),
#  Row(ts=1538354365000, page='NextSong', song='Dog Days Are Over (Radio Edit)'),
#  Row(ts=1538354584000, page='NextSong', song='Tomorrow Is A Long Time'),
#  Row(ts=1538354806000, page='NextSong', song='Halloween Spooks'),
#  Row(ts=1538354945000, page='NextSong', song='Stronger'),
#  Row(ts=1538355256000, page='NextSong', song='Dis Iz Brick City'),
#  Row(ts=1538355473000, page='NextSong', song='Move Along'),
#  Row(ts=1538355711000, page='NextSong', song='Manhattan'),
#  Row(ts=1538355915000, page='NextSong', song='Undo'),
#  Row(ts=1538356263000, page='NextSong', song='The Big Gundown'),
#  Row(ts=1538356523000, page='NextSong', song='Black Bird'),
#  Row(ts=1538356524000, page='Thumbs Down', song=None),
#  Row(ts=1538356707000, page='NextSong', song='Nausea'),
#  Row(ts=1538356903000, page='NextSong', song='Matricide'),
#  Row(ts=1538357223000, page='NextSong', song='Valerie'),
#  Row(ts=1538357452000, page='NextSong', song='Margarita'),
#  Row(ts=1538357648000, page='NextSong', song="Le Jardin d'Hiver"),
#  Row(ts=1538357649000, page='Thumbs Up', song=None),
#  Row(ts=1538357990000, page='NextSong', song='Soon As I Get Home(Album Version)'),
#  Row(ts=1538357991000, page='Thumbs Up', song=None),
#  Row(ts=1538358314000, page='NextSong', song='Vamos a la Playa'),
#  Row(ts=1538358532000, page='NextSong', song='Perfecta'),
#  Row(ts=1538358761000, page='NextSong', song='Requiem'),
#  Row(ts=1538359054000, page='NextSong', song='Who Can Compare'),
#  Row(ts=1538359320000, page='NextSong', song='240 Years Before Your Time'),
#  Row(ts=1538360720000, page='NextSong', song='Rosa Pastel'),
#  Row(ts=1538360737000, page='Roll Advert', song=None),
#  Row(ts=1538360905000, page='NextSong', song="I'm Ready (Album Version)"),
#  Row(ts=1538361107000, page='NextSong', song='No Other Saviour'),
#  Row(ts=1538361372000, page='NextSong', song='Hints'),
#  Row(ts=1538361540000, page='NextSong', song='Yellow'),
#  Row(ts=1538361575000, page='Add to Playlist', song=None),
#  Row(ts=1538810630000, page='NextSong', song='Kill The Director [Radio Edit]'),
#  Row(ts=1538810631000, page='Add Friend', song=None),
#  Row(ts=1538948226000, page='Home', song=None),
#  Row(ts=1538948240000, page='NextSong', song='Third Party'),
#  Row(ts=1538948591000, page='NextSong', song="It's Working"),
#  Row(ts=1538948837000, page='NextSong', song="I'll Remember April (Digitally Remastered 01)"),
#  Row(ts=1538949034000, page='NextSong', song='Atmosphere Station'),
#  Row(ts=1538949225000, page='NextSong', song='There_ There'),
#  Row(ts=1538949548000, page='NextSong', song="'Til We Die (Album Version)"),
#  Row(ts=1538949893000, page='NextSong', song='Lies (Album Version)'),
#  Row(ts=1538950072000, page='NextSong', song='The Ballad of Michael Valentine'),
#  Row(ts=1538950302000, page='NextSong', song='Gears'),
#  Row(ts=1538950541000, page='NextSong', song='These Eyes'),
#  Row(ts=1538950549000, page='Help', song=None),
#  Row(ts=1538950593000, page='Home', song=None),
#  Row(ts=1538950812000, page='NextSong', song='Stronger'),
#  Row(ts=1538951123000, page='NextSong', song='This Is Such A Pity'),
#  Row(ts=1538951327000, page='NextSong', song='Strut (1993 Digital Remaster)'),
#  Row(ts=1538951566000, page='NextSong', song='Fader'),
#  Row(ts=1538951758000, page='NextSong', song='Se Quiere_ Se Mata'),
#  Row(ts=1538951976000, page='NextSong', song='Somewhere'),
#  Row(ts=1538952145000, page='NextSong', song='Canada'),
#  Row(ts=1538952381000, page='NextSong', song='Dream On Dreamer'),
#  Row(ts=1538952621000, page='NextSong', song='HÃ\x83Â¡ Uma MÃ\x83Âºsica Do Povo (Live)'),
#  Row(ts=1538952837000, page='NextSong', song="Money Ain't A Thang"),
#  Row(ts=1538953091000, page='NextSong', song='Howlin\x19 For You'),
#  Row(ts=1538953282000, page='NextSong', song='Fireflies'),
#  Row(ts=1538953507000, page='NextSong', song='Stadium Love'),
#  Row(ts=1538953526000, page='Downgrade', song=None),
#  Row(ts=1538953759000, page='NextSong', song='Again & Again'),
#  Row(ts=1538953924000, page='NextSong', song='The Trooper (1998 Digital Remaster)'),
#  Row(ts=1538954176000, page='NextSong', song='Get Off My Elevator'),
#  Row(ts=1538954314000, page='NextSong', song='Speed Trials'),
#  Row(ts=1538954495000, page='NextSong', song='Invalid'),
#  Row(ts=1538954728000, page='NextSong', song='Frenchy\x19s'),
#  Row(ts=1538954902000, page='NextSong', song='Between Two Lungs'),
#  Row(ts=1538955151000, page='NextSong', song='Hiding'),
#  Row(ts=1538955377000, page='NextSong', song='Alone Again (Naturally)'),
#  Row(ts=1538955595000, page='NextSong', song='You Found Me'),
#  Row(ts=1538955835000, page='NextSong', song='Our Song'),
#  Row(ts=1538956036000, page='NextSong', song='Rock Hard'),
#  Row(ts=1538956230000, page='NextSong', song='Waiting For Tonight'),
#  Row(ts=1538956475000, page='NextSong', song='Pioneer to The Falls'),
#  Row(ts=1538956816000, page='NextSong', song="You're The One"),
#  Row(ts=1538957055000, page='NextSong', song='Trash And Ready'),
#  Row(ts=1538957228000, page='NextSong', song="Keep On Movin'"),
#  Row(ts=1538957589000, page='NextSong', song='Quase Um Segundo'),
#  Row(ts=1538957763000, page='NextSong', song='Costumbres Argentinas'),
#  Row(ts=1538957960000, page='NextSong', song='Nine Times Out Of Ten (1998 Digital Remaster)'),
#  Row(ts=1538958090000, page='NextSong', song='Bass Solo'),
#  Row(ts=1538958387000, page='NextSong', song='The Memory Remains'),
#  Row(ts=1538958666000, page='NextSong', song='Clock'),
#  Row(ts=1538958923000, page='NextSong', song='I Don\x19t Wanna Go To The Party'),
#  Row(ts=1538959027000, page='NextSong', song="She's So Cold"),
#  Row(ts=1538959280000, page='NextSong', song='Drops In The River'),
#  Row(ts=1538959533000, page='NextSong', song='Didgeridoo'),
#  Row(ts=1538959963000, page='NextSong', song='Sex_ Love & Money'),
#  Row(ts=1538960213000, page='NextSong', song='Rayando el sol'),
#  Row(ts=1538960465000, page='NextSong', song='Lights And Sounds'),
#  Row(ts=1538960673000, page='NextSong', song='You Make Me Wanna...'),
#  Row(ts=1538960992000, page='NextSong', song="When It's Love (Remastered Album Version)"),
#  Row(ts=1538961330000, page='NextSong', song='Red Tide'),
#  Row(ts=1538961486000, page='NextSong', song='Man Of Two Minds'),
#  Row(ts=1538961725000, page='NextSong', song='Ruled By Secrecy'),
#  Row(ts=1538962017000, page='NextSong', song='Untitled #5'),
#  Row(ts=1538962107000, page='NextSong', song='Misery Business (Single Version)'),
#  Row(ts=1538962305000, page='NextSong', song='Hold My Heart'),
#  Row(ts=1538962544000, page='NextSong', song='Risen (Rolling Stone Original)'),
#  Row(ts=1538962840000, page='NextSong', song='Sonne'),
#  Row(ts=1538962841000, page='Thumbs Up', song=None),
#  Row(ts=1538963112000, page='NextSong', song='Out Of Exile'),
#  Row(ts=1538963113000, page='Thumbs Up', song=None),
#  Row(ts=1538963400000, page='NextSong', song='Old Yellow Bricks'),
#  Row(ts=1538963591000, page='NextSong', song='GalÃ\x83Â©rer'),
#  Row(ts=1538963901000, page='NextSong', song='Casting A Spell (Remixed) (1998 Digital Remaster)'),
#  Row(ts=1538964128000, page='NextSong', song='Operation Uppsala'),
#  Row(ts=1538964389000, page='NextSong', song='Detached (Album Version)'),
#  Row(ts=1538964590000, page='NextSong', song='Echo Beach (2002 Digital Remaster)'),
#  Row(ts=1538964808000, page='NextSong', song='Te Va A Doler'),
#  Row(ts=1538965100000, page='NextSong', song='paranoid android'),
#  Row(ts=1538965154000, page='Home', song=None),
#  Row(ts=1538965437000, page='NextSong', song='Banned from Heaven'),
#  Row(ts=1538965741000, page='NextSong', song='Trashcan'),
#  Row(ts=1538965958000, page='NextSong', song='Go Go Gadget Flow (Explicit Album Version)'),
#  Row(ts=1538966208000, page='NextSong', song='Home For A Rest'),
#  Row(ts=1538966484000, page='NextSong', song="When You're Gone"),
#  Row(ts=1538966724000, page='NextSong', song='The Slam (Welcome To Diverse City Album Version)'),
#  Row(ts=1538966924000, page='NextSong', song='You Raise Me Up'),
#  Row(ts=1538966961000, page='Add to Playlist', song=None),
#  Row(ts=1538967205000, page='NextSong', song='There Is A Light That Never Goes Out'),
#  Row(ts=1538967447000, page='NextSong', song='The High Way'),
#  Row(ts=1538967448000, page='Thumbs Up', song=None),
#  Row(ts=1538967453000, page='Add to Playlist', song=None),
#  Row(ts=1538967726000, page='NextSong', song="The Final Episode (Let's Change The Channel)"),
#  Row(ts=1538967967000, page='NextSong', song='Candy'),
#  Row(ts=1538967968000, page='Thumbs Up', song=None),
#  Row(ts=1538967976000, page='Add to Playlist', song=None),
#  Row(ts=1538968163000, page='NextSong', song='re:stacks'),
#  Row(ts=1538968181000, page='Add to Playlist', song=None),
#  Row(ts=1538968565000, page='NextSong', song='Converting Vegetarians'),
#  Row(ts=1538968904000, page='NextSong', song='Airwar'),
#  Row(ts=1538969169000, page='NextSong', song='Unplayed Piano (Chris Lord-Alge Mix)'),
#  Row(ts=1538969397000, page='NextSong', song="Don't Mean Nothing"),
#  Row(ts=1538969679000, page='NextSong', song='Let Me'),
#  Row(ts=1538969967000, page='NextSong', song='Ã\x82Â¿Por quÃ\x83Â© te vas?'),
#  Row(ts=1538970249000, page='NextSong', song='In My Place'),
#  Row(ts=1538970477000, page='NextSong', song='Beautiful'),
#  Row(ts=1538970478000, page='Thumbs Up', song=None),
#  Row(ts=1538970847000, page='NextSong', song='Miniature Disasters'),
#  Row(ts=1538971054000, page='NextSong', song='Brothers In Arms'),
#  Row(ts=1538971191000, page='Home', song=None),
#  Row(ts=1538971204000, page='NextSong', song='Billy Breathes'),
#  Row(ts=1538971535000, page='NextSong', song='Revelry'),
#  Row(ts=1538971736000, page='NextSong', song='Ignition'),
#  Row(ts=1538971737000, page='Add Friend', song=None),
#  Row(ts=1538971968000, page='NextSong', song='Sweet Escape'),
#  Row(ts=1538972155000, page='NextSong', song='Disturbia Money'),
#  Row(ts=1538972366000, page='NextSong', song='15 Step'),
#  Row(ts=1538972603000, page='NextSong', song="Surfin' Bird"),
#  Row(ts=1538972604000, page='Thumbs Up', song=None),
#  Row(ts=1538972749000, page='NextSong', song='Strange Machines'),
#  Row(ts=1538973112000, page='NextSong', song='DÃ\x83Â¬'),
#  Row(ts=1538973235000, page='NextSong', song='Devotion And Desire'),
#  Row(ts=1538973529000, page='NextSong', song='The Fire Still Burns'),
#  Row(ts=1538973865000, page='NextSong', song='My Little Brother'),
#  Row(ts=1538974008000, page='NextSong', song="These Things You Can't Unlearn"),
#  Row(ts=1538974395000, page='NextSong', song='Nobody (Featuring Athena Cage) (LP Version)'),
#  Row(ts=1538974658000, page='NextSong', song='Mr. Jones'),
#  Row(ts=1538974930000, page='NextSong', song='You Had Me At Hello'),
#  Row(ts=1538975199000, page='NextSong', song='Rally'),
#  Row(ts=1538975394000, page='NextSong', song="Adam's Song"),
#  Row(ts=1538975640000, page='NextSong', song='Too Much'),
#  Row(ts=1538975892000, page='NextSong', song="I'm On A Boat"),
#  Row(ts=1538976048000, page='NextSong', song='Questo Pazzo Pazzo Mondo Di Tasse'),
#  Row(ts=1538976227000, page='NextSong', song='You Are Not Stubborn'),
#  Row(ts=1538976417000, page='NextSong', song='P.I.M.P.'),
#  Row(ts=1538976666000, page='NextSong', song='Explosive'),
#  Row(ts=1538976856000, page='NextSong', song='Conteo'),
#  Row(ts=1538977052000, page='NextSong', song='Blue'),
#  Row(ts=1538977053000, page='Thumbs Up', song=None),
#  Row(ts=1538977318000, page='NextSong', song='These Days'),
#  Row(ts=1538977336000, page='Home', song=None),
#  Row(ts=1538977616000, page='NextSong', song='Twenty-Six Temptations (Album version)'),
#  Row(ts=1538977868000, page='NextSong', song='Janglin'),
#  Row(ts=1538978097000, page='NextSong', song='I Write Sins Not Tragedies [Live In Chicago]'),
#  Row(ts=1538978294000, page='NextSong', song='Wore Out'),
#  Row(ts=1538978500000, page='NextSong', song='JOG-O-MOTION PART 1'),
#  Row(ts=1538978501000, page='Thumbs Up', song=None),
#  Row(ts=1538980515000, page='NextSong', song='No Remorse'),
#  Row(ts=1538980901000, page='NextSong', song='Small'),
#  Row(ts=1538981087000, page='NextSong', song='Cover Me'),
#  Row(ts=1538981272000, page='NextSong', song='No Air duet with Chris Brown'),
#  Row(ts=1538981536000, page='NextSong', song='Between Us And Them'),
#  Row(ts=1538981973000, page='NextSong', song='ParaÃ\x83Â\xadso'),
#  Row(ts=1538982201000, page='NextSong', song='Untitled'),
#  Row(ts=1538982367000, page='NextSong', song='Fire With Fire'),
#  Row(ts=1538982535000, page='NextSong', song='Rainbow'),
#  Row(ts=1538982771000, page='NextSong', song='Dusk Till Dawn'),
#  Row(ts=1538983127000, page='NextSong', song='Three Pope (feat. Monty Alexander)'),
#  Row(ts=1538983333000, page='NextSong', song='She Hates Me'),
#  Row(ts=1538983551000, page='NextSong', song="You'll Be In My Heart"),
#  Row(ts=1538983809000, page='NextSong', song='The Bunting Song'),
#  Row(ts=1538984035000, page='NextSong', song='Beer'),
#  Row(ts=1538984245000, page='NextSong', song='With Or Without You'),
#  Row(ts=1538984541000, page='NextSong', song='Going North [Commentary]'),
#  Row(ts=1538984631000, page='NextSong', song='Greece 2000'),
#  Row(ts=1538985042000, page='NextSong', song='What A Feeling'),
#  Row(ts=1538985043000, page='Thumbs Up', song=None),
#  Row(ts=1538985286000, page='NextSong', song='The Legend of Finn MacCumhail (Album Version)'),
#  Row(ts=1538985420000, page='NextSong', song='Love Story'),
#  Row(ts=1538985421000, page='Add Friend', song=None),
#  Row(ts=1538985422000, page='Add Friend', song=None),
#  Row(ts=1538985653000, page='NextSong', song='Gafas de pasta'),
#  Row(ts=1538985666000, page='Add to Playlist', song=None),
#  Row(ts=1538985765000, page='NextSong', song="You've Got A Friend (Live Version)"),
#  Row(ts=1538986039000, page='NextSong', song='Diamonds From Sierra Leone'),
#  Row(ts=1538986272000, page='NextSong', song='No Use'),
#  Row(ts=1538986292000, page='Settings', song=None),
#  Row(ts=1538986522000, page='NextSong', song='Bring Me To Life'),
#  Row(ts=1538986758000, page='NextSong', song='Be Like You'),
#  Row(ts=1538986954000, page='NextSong', song='U.S. History'),
#  Row(ts=1538987267000, page='NextSong', song='La Cocinera'),
#  Row(ts=1538987268000, page='Thumbs Up', song=None),
#  Row(ts=1538987470000, page='NextSong', song='All Summer Long'),
#  Row(ts=1538987780000, page='NextSong', song="D'Evils"),
#  Row(ts=1538987992000, page='NextSong', song='Hard To Concentrate (Album Version)'),
#  Row(ts=1538988233000, page='NextSong', song='Bad Omen (24-Bit Digitally Remastered 04) ()'),
#  Row(ts=1538988476000, page='NextSong', song='Put Your Hands Up For Detroit'),
#  Row(ts=1538988872000, page='NextSong', song='Bad Trails'),
#  Row(ts=1538989190000, page='NextSong', song='Bring Me Down'),
#  Row(ts=1538989460000, page='NextSong', song='Last Time (Album Version)'),
#  Row(ts=1538989626000, page='NextSong', song='Apply Some Pressure'),
#  Row(ts=1538989842000, page='NextSong', song='Tailor Made'),
#  Row(ts=1538990110000, page='NextSong', song='I Can Tell'),
#  Row(ts=1538990348000, page='NextSong', song='Angels We Have Heard On High'),
#  Row(ts=1538990355000, page='Add to Playlist', song=None),
#  Row(ts=1538990608000, page='NextSong', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(ts=1538990789000, page='NextSong', song='Picture Perfect'),
#  Row(ts=1538990811000, page='Error', song=None),
#  Row(ts=1538990964000, page='NextSong', song='Ours Alone'),
#  Row(ts=1538991359000, page='NextSong', song='Master Of Puppets'),
#  Row(ts=1538991874000, page='NextSong', song='Costruire'),
#  Row(ts=1538992187000, page='NextSong', song='Sparks'),
#  Row(ts=1538992508000, page='NextSong', song='Wildlife'),
#  Row(ts=1538993164000, page='NextSong', song='Hello'),
#  Row(ts=1538993384000, page='NextSong', song='Even If Kills Me (Cd)'),
#  Row(ts=1538993615000, page='NextSong', song='Drinking In L.A.'),
#  Row(ts=1538993850000, page='NextSong', song='Xehasmeni Melodia'),
#  Row(ts=1538994156000, page='NextSong', song="You Can't Break A Broken Heart"),
#  Row(ts=1538994201000, page='Downgrade', song=None),
#  Row(ts=1538994374000, page='NextSong', song='Truth In The Age Of Lies (Album Version)'),
#  Row(ts=1538994562000, page='NextSong', song='Donde Vamos'),
#  Row(ts=1538994832000, page='NextSong', song="Lady '95"),
#  Row(ts=1538995016000, page='NextSong', song='Horseshoes and Hand Grenades'),
#  Row(ts=1538995447000, page='NextSong', song='Jamaica Roots II(Agora E Sempre)'),
#  Row(ts=1538995453000, page='Downgrade', song=None),
#  Row(ts=1538995454000, page='Submit Downgrade', song=None),
#  Row(ts=1538995509000, page='Home', song=None),
#  Row(ts=1538995657000, page='NextSong', song='Crimewave (Crystal Castles vs Health)'),
#  Row(ts=1538995915000, page='NextSong', song='Hey (Album Version)'),
#  Row(ts=1538996254000, page='NextSong', song='I Believe In Forever'),
#  Row(ts=1538996261000, page='Add to Playlist', song=None),
#  Row(ts=1538996451000, page='NextSong', song="Don't Stop The Music"),
#  Row(ts=1538996718000, page='NextSong', song='City Of The Dead'),
#  Row(ts=1538996862000, page='NextSong', song='Too Afraid To Love'),
#  Row(ts=1538996870000, page='Home', song=None),
#  Row(ts=1538997066000, page='NextSong', song='Hasir'),
#  Row(ts=1538997356000, page='NextSong', song='Bloat On (featuring the Bloaters) (LP Version)'),
#  Row(ts=1538997655000, page='NextSong', song="Frisch und g'sund"),
#  Row(ts=1538997824000, page='NextSong', song='Boom Boom'),
#  Row(ts=1538997825000, page='Thumbs Up', song=None),
#  Row(ts=1538998102000, page='NextSong', song='Undo'),
#  Row(ts=1538998114000, page='Add to Playlist', song=None),
#  Row(ts=1538998450000, page='NextSong', song='Hunting For Witches'),
#  Row(ts=1538998660000, page='NextSong', song='Blindsided'),
#  Row(ts=1538998989000, page='NextSong', song='Survive'),
#  Row(ts=1538999210000, page='NextSong', song='Alice'),
#  Row(ts=1538999425000, page='NextSong', song='Dog Days Are Over (Radio Edit)'),
#  Row(ts=1538999644000, page='NextSong', song="Lovin' You"),
#  Row(ts=1538999867000, page='NextSong', song="Everybody's Fool (Live in Europe)"),
#  Row(ts=1539000087000, page='NextSong', song='Jeune Et Con'),
#  Row(ts=1539000321000, page='NextSong', song='Somebody (Loves You) (Explicit Album Version)'),
#  Row(ts=1539000599000, page='NextSong', song='Not Big'),
#  Row(ts=1539000795000, page='NextSong', song='Paint You'),
#  Row(ts=1539000918000, page='NextSong', song='Block Of Ice'),
#  Row(ts=1539000958000, page='Upgrade', song=None),
#  Row(ts=1539001052000, page='NextSong', song='Sun It Rises'),
#  Row(ts=1539001077000, page='Upgrade', song=None),
#  Row(ts=1539001243000, page='NextSong', song='Paralyzer'),
#  Row(ts=1539001451000, page='NextSong', song='Bleed It Out [Live At Milton Keynes]'),
#  Row(ts=1539001513000, page='Add to Playlist', song=None),
#  Row(ts=1539001945000, page='NextSong', song='Ven Conmigo (Solamente TÃ\x83Âº)'),
#  Row(ts=1539002135000, page='NextSong', song='Give In'),
#  Row(ts=1539002303000, page='NextSong', song='Arrepentida'),
#  Row(ts=1539002562000, page='NextSong', song="I Don't Want To Wait (Album Version)"),
#  Row(ts=1539002881000, page='NextSong', song='Down To The River To Pray'),
#  Row(ts=1539003010000, page='NextSong', song='Castles In The Sky'),
#  Row(ts=1539003011000, page='Thumbs Up', song=None),
#  Row(ts=1539003233000, page='NextSong', song='Sitting On Top Of The World'),
#  Row(ts=1539003419000, page='NextSong', song='The Way Things Go'),
#  Row(ts=1539003841000, page='NextSong', song='Recruiting Soldiers (2002 Digital Remaster)'),
#  Row(ts=1539003842000, page='Thumbs Up', song=None),
#  Row(ts=1539004108000, page='NextSong', song='Clara meets Slope - Hard To Say'),
#  Row(ts=1539004374000, page='NextSong', song='Timeless'),
#  Row(ts=1539004480000, page='NextSong', song="Punta D'Alba"),
#  Row(ts=1539004502000, page='Roll Advert', song=None),
#  Row(ts=1539004882000, page='NextSong', song="Ghosts 'n' Stuff (Original Instrumental Mix)"),
#  Row(ts=1539005256000, page='NextSong', song="I Couldn't Help It If I Tried"),
#  Row(ts=1539005507000, page='NextSong', song='The Blood_ The Sweat_ The Tears (Album Version)'),
#  Row(ts=1539005525000, page='Add to Playlist', song=None),
#  Row(ts=1539005758000, page='NextSong', song='She Said'),
#  Row(ts=1539005788000, page='Home', song=None),
#  Row(ts=1539005966000, page='NextSong', song='Undo'),
#  Row(ts=1539006314000, page='NextSong', song='Bust A Move'),
#  Row(ts=1539006315000, page='Thumbs Up', song=None),
#  Row(ts=1539006578000, page='NextSong', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(ts=1539006759000, page='NextSong', song='White Light/White Heat'),
#  Row(ts=1539006924000, page='NextSong', song='Infinity'),
#  Row(ts=1539007237000, page='NextSong', song='Bros Sto Rimagmeno Spiti (2003 Digital Remaster)'),
#  Row(ts=1539007238000, page='Add Friend', song=None),
#  Row(ts=1539007239000, page='Add Friend', song=None),
#  Row(ts=1539007249000, page='Home', song=None),
#  Row(ts=1539007438000, page='NextSong', song='Gear Box'),
#  Row(ts=1539007439000, page='Roll Advert', song=None),
#  Row(ts=1539007649000, page='NextSong', song='In Liverpool'),
#  Row(ts=1539007935000, page='NextSong', song='Work It Out'),
#  Row(ts=1539008179000, page='NextSong', song='Timberwolves At New Jersey (Album Version)'),
#  Row(ts=1539008217000, page='Home', song=None),
#  Row(ts=1539008382000, page='NextSong', song='Great Escape'),
#  Row(ts=1539008779000, page='NextSong', song='Drop The World'),
#  Row(ts=1539009008000, page='NextSong', song='My Poor Old Heart'),
#  Row(ts=1539009195000, page='NextSong', song='Hey! (A Lil Gratitude) (Album Version) ()'),
#  Row(ts=1539158867000, page='Home', song=None),
#  Row(ts=1539158890000, page='NextSong', song='Map Of The Problematique'),
#  Row(ts=1539159148000, page='NextSong', song='Gente Que No'),
#  Row(ts=1539159403000, page='NextSong', song='Half Of My Heart'),
#  Row(ts=1539159653000, page='NextSong', song='All My Love'),
#  Row(ts=1539159936000, page='NextSong', song='Dog Eat Dog'),
#  Row(ts=1539273182000, page='Home', song=None),
#  Row(ts=1539273245000, page='Home', song=None),
#  Row(ts=1539275685000, page='Home', song=None),
#  Row(ts=1539275691000, page='NextSong', song='The Laws Have Changed'),
#  Row(ts=1539275897000, page='NextSong', song="She's My Baby"),
#  Row(ts=1539276162000, page='NextSong', song="Don't Give Up On Us"),
#  Row(ts=1539276378000, page='NextSong', song="What's Left of the Flag"),
#  Row(ts=1539276711000, page='NextSong', song='Why Do You Laugh At Me'),
#  Row(ts=1539276950000, page='NextSong', song='Eskimo - Album Version (not as hidden track)'),
#  Row(ts=1539276951000, page='Roll Advert', song=None),
#  Row(ts=1539277255000, page='NextSong', song='A Beggar On A Beach Of Gold'),
#  Row(ts=1539277261000, page='Upgrade', song=None),
#  Row(ts=1539277530000, page='NextSong', song='Ragoo'),
#  Row(ts=1539277711000, page='NextSong', song='Unreachable'),
#  Row(ts=1539277944000, page='NextSong', song='Misunderstood'),
#  Row(ts=1539278183000, page='NextSong', song='Seize The Day (Album Version)'),
#  Row(ts=1539278516000, page='NextSong', song='All Over Again (Album Version)'),
#  Row(ts=1539278732000, page='NextSong', song='Car (Album)'),
#  Row(ts=1539278911000, page='NextSong', song="You're The One"),
#  Row(ts=1539279119000, page='NextSong', song='(You Drive Me) Crazy (The Stop Remix!)'),
#  Row(ts=1539279316000, page='NextSong', song='The Battery'),
#  Row(ts=1539279636000, page='NextSong', song='Ordinary Man'),
#  Row(ts=1539279892000, page='NextSong', song="I CAN'T GET STARTED"),
#  Row(ts=1539279893000, page='Thumbs Up', song=None),
#  Row(ts=1539280389000, page='NextSong', song='Corrido Al Torero'),
#  Row(ts=1539280570000, page='NextSong', song='Dull Life'),
#  Row(ts=1539280818000, page='NextSong', song='Aht Uh Mi Hed'),
#  Row(ts=1539280865000, page='Roll Advert', song=None),
#  Row(ts=1539280873000, page='Roll Advert', song=None),
#  Row(ts=1539295537000, page='NextSong', song='Fisticuffs (LP Version)'),
#  Row(ts=1539295687000, page='NextSong', song='More Than This'),
#  Row(ts=1539295921000, page='NextSong', song='Baby I Want You'),
#  Row(ts=1539296099000, page='NextSong', song='I Miss You'),
#  Row(ts=1539296131000, page='Roll Advert', song=None),
#  Row(ts=1539296336000, page='NextSong', song='Alejate De Mi'),
#  Row(ts=1539296594000, page='NextSong', song='Crazy Bitch (Album Version)'),
#  Row(ts=1539296795000, page='NextSong', song='Por segunda vez'),
#  Row(ts=1539296796000, page='Thumbs Up', song=None),
#  Row(ts=1539297021000, page='NextSong', song='Antibodies'),
#  Row(ts=1539297304000, page='NextSong', song='Toxic Girl'),
#  Row(ts=1539297491000, page='NextSong', song='Lowlands'),
#  Row(ts=1539297690000, page='NextSong', song='Even Deeper'),
#  Row(ts=1539297701000, page='Roll Advert', song=None),
#  Row(ts=1539298037000, page='NextSong', song='I Second That Emotion'),
#  Row(ts=1539298205000, page='NextSong', song='Scatman (Ski-Ba-Bop-Ba-Dop-Bop)'),
#  Row(ts=1539298417000, page='NextSong', song='Countdown'),
#  Row(ts=1539298608000, page='NextSong', song='Forever'),
#  Row(ts=1539298965000, page='NextSong', song='Bootzilla'),
#  Row(ts=1539298966000, page='Thumbs Up', song=None),
#  Row(ts=1539299301000, page='NextSong', song="I'd Rather Fuck You (Explicit) (Feat. Eazy-E)"),
#  Row(ts=1539299538000, page='NextSong', song='New Generation'),
#  Row(ts=1539299650000, page='NextSong', song='Follow You'),
#  Row(ts=1539299863000, page='NextSong', song='Shine On (Album Version)'),
#  Row(ts=1539300139000, page='NextSong', song='Venice Queen (Album Version)'),
#  Row(ts=1539300506000, page='NextSong', song='Tear You Apart'),
#  Row(ts=1539300790000, page='NextSong', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(ts=1539300791000, page='Thumbs Up', song=None),
#  Row(ts=1539301067000, page='NextSong', song='Over Now'),
#  Row(ts=1539301073000, page='Upgrade', song=None),
#  Row(ts=1539301490000, page='NextSong', song='Superbeast'),
#  Row(ts=1539301491000, page='Logout', song=None),
#  Row(ts=1539615637000, page='Home', song=None),
#  Row(ts=1539615678000, page='NextSong', song='Broke Up The Time'),
#  Row(ts=1539615704000, page='Add to Playlist', song=None),
#  Row(ts=1539615872000, page='NextSong', song='Roll Over Beethoven'),
#  Row(ts=1539616019000, page='NextSong', song='Way Back Home'),
#  Row(ts=1539616193000, page='NextSong', song='Back To Life (Album Version)'),
#  Row(ts=1539616464000, page='NextSong', song='Strut (1993 Digital Remaster)'),
#  Row(ts=1539616703000, page='NextSong', song='Super Inuit (Studio) [Bonus Track]'),
#  Row(ts=1539616926000, page='NextSong', song='16 Candles'),
#  Row(ts=1539617108000, page='NextSong', song='The Outlaw'),
#  Row(ts=1539617340000, page='NextSong', song='Geek In The Pink [Phil Tan Remix]'),
#  Row(ts=1539617558000, page='NextSong', song='The Chosen Legacy'),
#  Row(ts=1539617817000, page='NextSong', song="Don't You Run With Him"),
#  Row(ts=1539617871000, page='Roll Advert', song=None),
#  Row(ts=1539618035000, page='NextSong', song='Brianstorm'),
#  Row(ts=1539618207000, page='NextSong', song='To Zion'),
#  Row(ts=1539618210000, page='Home', song=None),
#  Row(ts=1539618576000, page='NextSong', song='Lucy (Album Version)'),
#  Row(ts=1539618794000, page='NextSong', song='What Goes Around...Comes Around'),
#  Row(ts=1539619107000, page='NextSong', song='Bang On The Drum'),
#  Row(ts=1539619321000, page='NextSong', song='Bill Sykes'),
#  Row(ts=1539619461000, page='NextSong', song='Rhyme & Reason'),
#  Row(ts=1539619819000, page='NextSong', song='Schifrin and Variations'),
#  Row(ts=1539619820000, page='Thumbs Up', song=None),
#  Row(ts=1539620003000, page='NextSong', song='Teach Me How To Dougie'),
#  Row(ts=1539620242000, page='NextSong', song='We Deal In Dreams'),
#  Row(ts=1539620475000, page='NextSong', song='Undo'),
#  Row(ts=1539620823000, page='NextSong', song='Pushing Me Away (Album Version)'),
#  Row(ts=1539620841000, page='Roll Advert', song=None),
#  Row(ts=1539620842000, page='Logout', song=None),
#  Row(ts=1539620843000, page='Home', song=None),
#  Row(ts=1539621014000, page='NextSong', song='Trouble Dub - FAMS Mix'),
#  Row(ts=1539621224000, page='NextSong', song='Electric Avenue'),
#  Row(ts=1539621448000, page='NextSong', song="If I Ain't Got You"),
#  Row(ts=1539621468000, page='Roll Advert', song=None),
#  Row(ts=1539621525000, page='Roll Advert', song=None),
#  Row(ts=1539621677000, page='NextSong', song='Dream'),
#  Row(ts=1539621922000, page='NextSong', song='Pak Dit Grej (1998 Digital Remaster)'),
#  Row(ts=1539622195000, page='NextSong', song='My Moon My Man'),
#  Row(ts=1539622196000, page='Thumbs Up', song=None),
#  Row(ts=1539622379000, page='NextSong', song='Constellations'),
#  Row(ts=1539622580000, page='NextSong', song='Kiss (LP Version)'),
#  Row(ts=1539622807000, page='NextSong', song='Ven AquÃ\x83Â\xad'),
#  Row(ts=1539623024000, page='NextSong', song='Christmas Journey'),
#  Row(ts=1539623176000, page='NextSong', song='Little Fighter'),
#  Row(ts=1539623471000, page='NextSong', song='Always Coming Back Home To You'),
#  Row(ts=1539624022000, page='NextSong', song='Alarm!'),
#  Row(ts=1539624190000, page='NextSong', song='Run'),
#  Row(ts=1539624635000, page='NextSong', song='Do You Dream'),
#  Row(ts=1539625095000, page='NextSong', song='The Only Exception (Album Version)'),
#  Row(ts=1539625118000, page='Roll Advert', song=None),
#  Row(ts=1539625362000, page='NextSong', song='Spiderwebs'),
#  Row(ts=1539625628000, page='NextSong', song="Please Don't Go"),
#  Row(ts=1539625638000, page='Add to Playlist', song=None),
#  Row(ts=1539625896000, page='NextSong', song='Pursuit Of Happiness (nightmare)'),
#  Row(ts=1539626191000, page='NextSong', song="Breakin' Dishes"),
#  Row(ts=1539626391000, page='NextSong', song='Hall of Fame'),
#  Row(ts=1539626544000, page='NextSong', song='Brothers'),
#  Row(ts=1539626970000, page='NextSong', song='Hide & Seek'),
#  Row(ts=1539626977000, page='Add to Playlist', song=None),
#  Row(ts=1539627479000, page='NextSong', song="It's No Good (Single Version)"),
#  Row(ts=1539627836000, page='NextSong', song='Here We Are (Family In The Hallways)'),
#  Row(ts=1539628056000, page='NextSong', song='Love Is Blue'),
#  Row(ts=1539628057000, page='Thumbs Up', song=None),
#  Row(ts=1539628209000, page='NextSong', song='Wounded'),
#  Row(ts=1539628414000, page='NextSong', song='Selling The Drama'),
#  Row(ts=1539628619000, page='NextSong', song='My Michelle'),
#  Row(ts=1539628620000, page='Logout', song=None),
#  Row(ts=1539628843000, page='Home', song=None),
#  Row(ts=1539628852000, page='NextSong', song='Superstition'),
#  Row(ts=1539629132000, page='NextSong', song='The Scientist'),
#  Row(ts=1539629166000, page='Help', song=None),
#  Row(ts=1539629443000, page='NextSong', song='Make Love To Your Mind'),
#  Row(ts=1539629826000, page='NextSong', song='Art is Hard'),
#  Row(ts=1539629830000, page='Home', song=None),
#  Row(ts=1539629831000, page='Add Friend', song=None),
#  Row(ts=1539629845000, page='Settings', song=None),
#  Row(ts=1539731438000, page='Home', song=None),
#  Row(ts=1539731439000, page='Logout', song=None),
#  Row(ts=1540070969000, page='Home', song=None),
#  Row(ts=1540268084000, page='NextSong', song='Silent Running'),
#  Row(ts=1540268509000, page='NextSong', song='The Unforgiven II'),
#  Row(ts=1540268905000, page='NextSong', song="Valjean's Soliloquy"),
#  Row(ts=1540269124000, page='NextSong', song='Tonight'),
#  Row(ts=1540269342000, page='NextSong', song='Playing To Win (24-Bit Digitally Remastered 02)'),
#  Row(ts=1540269519000, page='NextSong', song='El nazareno'),
#  Row(ts=1540269856000, page='NextSong', song='Your Song'),
#  Row(ts=1540270093000, page='NextSong', song='Thunderbird'),
#  Row(ts=1540270415000, page='NextSong', song='Rayando el sol'),
#  Row(ts=1540270667000, page='NextSong', song='Mama Your Boys Will Find A Home'),
#  Row(ts=1540270895000, page='NextSong', song='Absolution: Of Flight and Failure'),
#  Row(ts=1540271283000, page='NextSong', song='The Bones Of You'),
#  Row(ts=1540271574000, page='NextSong', song='Kickstarts'),
#  Row(ts=1540271754000, page='NextSong', song='Mrs. Robinson (LP Version)'),
#  Row(ts=1540271765000, page='Add to Playlist', song=None),
#  Row(ts=1540271974000, page='NextSong', song='Rain Is A Good Thing'),
#  Row(ts=1540272149000, page='NextSong', song='Barco a Venus'),
#  Row(ts=1540272357000, page='NextSong', song='Planet Caravan (Remastered LP Version)'),
#  Row(ts=1540272601000, page='NextSong', song='I Melt With You'),
#  Row(ts=1540272878000, page='NextSong', song='Failures Burden'),
#  Row(ts=1540272903000, page='Roll Advert', song=None),
#  Row(ts=1540273275000, page='NextSong', song='I Get It'),
#  Row(ts=1540273490000, page='NextSong', song='Lie To Me'),
#  Row(ts=1540273497000, page='Add to Playlist', song=None),
#  Row(ts=1540273708000, page='NextSong', song="Sonny's Dream"),
#  Row(ts=1540273724000, page='Roll Advert', song=None),
#  Row(ts=1540273892000, page='NextSong', song='Mandy'),
#  Row(ts=1540273893000, page='Thumbs Down', song=None),
#  Row(ts=1540274114000, page='NextSong', song='Still'),
#  Row(ts=1540274147000, page='Roll Advert', song=None),
#  Row(ts=1540274345000, page='NextSong', song='Future Says Run'),
#  Row(ts=1540549210000, page='NextSong', song='Not So Usual (Eagles Ballroom Live Version)'),
#  Row(ts=1540549423000, page='NextSong', song='Troublemaker'),
#  Row(ts=1540549424000, page='Thumbs Up', song=None),
#  Row(ts=1540549587000, page='NextSong', song="Our Lawyer Made Us Change The Name Of This Song So We Wouldn't Get Sued"),
#  Row(ts=1540549777000, page='NextSong', song='The Vanishing'),
#  Row(ts=1540549897000, page='Home', song=None),
#  Row(ts=1540550054000, page='NextSong', song='Forget Me'),
#  Row(ts=1540550632000, page='NextSong', song='Wayfaring Stranger'),
#  Row(ts=1540550953000, page='NextSong', song='The Runner'),
#  Row(ts=1540551209000, page='NextSong', song='Harder To Breathe'),
#  Row(ts=1540551210000, page='Thumbs Up', song=None),
#  Row(ts=1540551382000, page='NextSong', song='Rain'),
#  Row(ts=1540551589000, page='NextSong', song='Bon Voyage'),
#  Row(ts=1540551723000, page='NextSong', song='Calm Down Dearest (Explicit)'),
#  Row(ts=1540552003000, page='NextSong', song="What's Left of the Flag"),
#  Row(ts=1540552336000, page='NextSong', song='Enigma (Album Version)'),
#  Row(ts=1540552616000, page='NextSong', song='Lay Me Down'),
#  Row(ts=1540552798000, page='NextSong', song='I Repeat'),
#  Row(ts=1540553040000, page='NextSong', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(ts=1540553221000, page='NextSong', song='Burgalveist'),
#  Row(ts=1540553391000, page='NextSong', song="It's Time I Go (Jazz)"),
#  Row(ts=1540553639000, page='NextSong', song='COLORADOSUNRISE (Explicit Album Version)'),
#  Row(ts=1540553841000, page='NextSong', song='Deseret'),
#  Row(ts=1540554075000, page='NextSong', song='Pink'),
#  Row(ts=1540554078000, page='Settings', song=None),
#  Row(ts=1540554310000, page='NextSong', song='Ras Trent'),
#  Row(ts=1540554315000, page='Roll Advert', song=None),
#  Row(ts=1540554435000, page='NextSong', song="Help I'm Alive"),
#  Row(ts=1540554721000, page='NextSong', song="Prodigal Son (Harvey's A Star In Your Own Mind Mix)"),
#  Row(ts=1540555327000, page='NextSong', song='Rhinestone Eyes'),
#  Row(ts=1540555328000, page='Add Friend', song=None),
#  Row(ts=1540555527000, page='NextSong', song="When It's Over (Remastered Album Version)"),
#  Row(ts=1540555745000, page='NextSong', song='Punch Drunk Love'),
#  Row(ts=1540568189000, page='NextSong', song="She's Got The Time"),
#  Row(ts=1540568269000, page='NextSong', song='The Strength To Go On'),
#  Row(ts=1540568476000, page='NextSong', song='The Stakes Are High'),
#  Row(ts=1540652942000, page='NextSong', song="Hustler's Prayer"),
#  Row(ts=1540653229000, page='NextSong', song='Fleur blanche'),
#  Row(ts=1540653230000, page='Thumbs Down', song=None),
#  Row(ts=1540653473000, page='NextSong', song='Live And Let Die'),
#  Row(ts=1540653657000, page='NextSong', song='Fast As I Can'),
#  Row(ts=1540653995000, page='NextSong', song='One In A Million'),
#  Row(ts=1540654207000, page='NextSong', song='Book Of Brilliant Things (2002 Digital Remaster)'),
#  Row(ts=1540654469000, page='NextSong', song='Glad All Over'),
#  Row(ts=1540654629000, page='NextSong', song='Arma dispuesta'),
#  Row(ts=1540654766000, page='NextSong', song='Heavyweight'),
#  Row(ts=1540654790000, page='Roll Advert', song=None),
#  Row(ts=1540655287000, page='NextSong', song='Deeply Disturbed'),
#  Row(ts=1540655793000, page='NextSong', song='Signifying'),
#  Row(ts=1540655973000, page='NextSong', song='Boy From School (Hot Chip Re-Work)'),
#  Row(ts=1540656011000, page='Roll Advert', song=None),
#  Row(ts=1540656404000, page='NextSong', song='Sehr kosmisch'),
#  Row(ts=1540657059000, page='NextSong', song='Clocks'),
#  Row(ts=1540657103000, page='Roll Advert', song=None),
#  Row(ts=1540657366000, page='NextSong', song='Shut Up & Kiss Me'),
#  Row(ts=1540657586000, page='NextSong', song='Use Somebody'),
#  Row(ts=1540657817000, page='NextSong', song='Sparkover'),
#  Row(ts=1540658327000, page='NextSong', song='Do You Feel Their Pain?'),
#  Row(ts=1540658713000, page='NextSong', song='Back Against The Wall'),
#  Row(ts=1540658715000, page='Home', song=None),
#  Row(ts=1540658941000, page='NextSong', song='Lonely'),
#  Row(ts=1540658966000, page='Roll Advert', song=None),
#  Row(ts=1540659127000, page='NextSong', song='It Was A Good Day'),
#  Row(ts=1540659379000, page='NextSong', song='Bliss'),
#  Row(ts=1540659631000, page='NextSong', song='Marry Me'),
#  Row(ts=1540659661000, page='Add to Playlist', song=None),
#  Row(ts=1540659836000, page='NextSong', song='Paint The Town Red'),
#  Row(ts=1540660086000, page='NextSong', song='Butterfly'),
#  Row(ts=1540660303000, page='NextSong', song='The Breaking of the Dawn (LP Version)'),
#  Row(ts=1540660592000, page='NextSong', song='Prenzlauerberg'),
#  Row(ts=1540660818000, page='NextSong', song='Not Fair (Clean Radio Edit)'),
#  Row(ts=1540660819000, page='Logout', song=None),
#  Row(ts=1540660921000, page='Home', song=None),
#  Row(ts=1540661019000, page='NextSong', song='Ribbons'),
#  Row(ts=1540661340000, page='NextSong', song='Please Forgive Me'),
#  Row(ts=1540661695000, page='NextSong', song='Kiss With A Fist'),
#  Row(ts=1540661826000, page='NextSong', song='Surf Wax America'),
#  Row(ts=1540662067000, page='NextSong', song='Smooth Sailing Remix'),
#  Row(ts=1540662083000, page='Settings', song=None),
#  Row(ts=1540662244000, page='NextSong', song='Hey Baby'),
#  Row(ts=1540662538000, page='NextSong', song='Pump It'),
#  Row(ts=1540662539000, page='Roll Advert', song=None),
#  Row(ts=1540662752000, page='NextSong', song='Superballs'),
#  Row(ts=1540662944000, page='NextSong', song='Away From Me'),
#  Row(ts=1540663185000, page='NextSong', song='The shooting company of Captain Frans B.Cocq'),
#  Row(ts=1540663662000, page='NextSong', song='Just'),
#  Row(ts=1540663896000, page='NextSong', song='Le Soir'),
#  Row(ts=1540663929000, page='Settings', song=None),
#  Row(ts=1540664072000, page='NextSong', song='Thursday'),
#  Row(ts=1540664328000, page='NextSong', song='Waiting For 22'),
#  Row(ts=1540664393000, page='NextSong', song='C-Town'),
#  Row(ts=1540664698000, page='NextSong', song='Never Again'),
#  Row(ts=1540664958000, page='NextSong', song='I Love You'),
#  Row(ts=1540665163000, page='NextSong', song='Appointment With Death'),
#  Row(ts=1540665390000, page='NextSong', song='Even The Streets'),
#  Row(ts=1540665706000, page='NextSong', song='Opis Helpus'),
#  Row(ts=1540988569000, page='NextSong', song='Sehr kosmisch'),
#  Row(ts=1540988576000, page='Roll Advert', song=None),
#  Row(ts=1540989224000, page='NextSong', song='Nueve Y Quince (9:15)'),
#  Row(ts=1540989488000, page='NextSong', song='Invocation: Attica Blues'),
#  Row(ts=1540989510000, page='NextSong', song='Birds'),
#  Row(ts=1540989775000, page='NextSong', song='Picture'),
#  Row(ts=1540989776000, page='Thumbs Up', song=None),
#  Row(ts=1540989791000, page='Add to Playlist', song=None),
#  Row(ts=1540990073000, page='NextSong', song='Half Of My Heart'),
#  Row(ts=1540990323000, page='NextSong', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(ts=1540990504000, page='NextSong', song='Gan Haedden (Edden)'),
#  Row(ts=1540990549000, page='NextSong', song='Collide'),
#  Row(ts=1540990826000, page='NextSong', song='Tan Solo (En Vivo)'),
#  Row(ts=1540990827000, page='Logout', song=None),
#  Row(ts=1540990864000, page='Home', song=None),
#  Row(ts=1540991077000, page='NextSong', song="Everything's Gonna Be Alright"),
#  Row(ts=1540991232000, page='NextSong', song='The Happy Song'),
#  Row(ts=1540991472000, page='NextSong', song='My Axe'),
#  Row(ts=1540991705000, page='NextSong', song='Home Is Where (Scavenged Luxury EP)'),
#  Row(ts=1540991831000, page='NextSong', song='The Scientist'),
#  Row(ts=1540991842000, page='Roll Advert', song=None),
#  Row(ts=1540992142000, page='NextSong', song='Deny Selected'),
#  Row(ts=1540992218000, page='Roll Advert', song=None),
#  Row(ts=1540992321000, page='NextSong', song='Late Nights'),
#  Row(ts=1540992567000, page='NextSong', song='The Scientist'),
#  Row(ts=1540992878000, page='NextSong', song='10%'),
#  Row(ts=1540993123000, page='NextSong', song='Beds Are Burning'),
#  Row(ts=1540993378000, page='NextSong', song='Relax'),
#  Row(ts=1540993615000, page='NextSong', song='Revelry'),
#  Row(ts=1540993621000, page='Upgrade', song=None),
#  Row(ts=1540993622000, page='Add Friend', song=None),
#  Row(ts=1540993705000, page='About', song=None),
#  Row(ts=1540993816000, page='NextSong', song="Dancin' On The Killing Floor"),
#  Row(ts=1540994033000, page='NextSong', song='Undo'),
#  Row(ts=1540994381000, page='NextSong', song='Te Hacen Falta Vitaminas'),
#  Row(ts=1540994382000, page='Thumbs Up', song=None),
#  Row(ts=1540994539000, page='NextSong', song='U Smile'),
#  Row(ts=1540994735000, page='NextSong', song='Smile'),
#  Row(ts=1540994929000, page='NextSong', song='Angels Fall First'),
#  Row(ts=1540995263000, page='NextSong', song='Sehr kosmisch'),
#  Row(ts=1540995277000, page='Home', song=None),
#  Row(ts=1540995918000, page='NextSong', song='Meeting Daisy'),
#  Row(ts=1540995999000, page='NextSong', song='El nazareno'),
#  Row(ts=1540996000000, page='Thumbs Up', song=None),
#  Row(ts=1540996336000, page='NextSong', song='Bat Country (Album Version)'),
#  Row(ts=1540996648000, page='NextSong', song='Sinisten tÃ\x83Â¤htien alla'),
#  Row(ts=1540996984000, page='NextSong', song='Deadweight On Velveteen'),
#  Row(ts=1540997191000, page='NextSong', song='Crank That (Soulja Boy)'),
#  Row(ts=1540997415000, page='NextSong', song='Recado Falado (MetrÃ\x83Â´ Da Saudade)'),
#  Row(ts=1540997577000, page='NextSong', song="It's OK"),
#  Row(ts=1540997816000, page='NextSong', song="Can't Stop This"),
#  Row(ts=1540998331000, page='NextSong', song="You're The One"),
#  Row(ts=1540998570000, page='NextSong', song='DONTTRUSTME [BENNYBLANCOREMIX] FEATURINGKIDCUDI (Explicit Bonus Version)'),
#  Row(ts=1540998766000, page='NextSong', song='The Grease Mega-Mix'),
#  Row(ts=1540999056000, page='NextSong', song='Snuff'),
#  Row(ts=1540999375000, page='NextSong', song='Runaway Love'),
#  Row(ts=1540999587000, page='NextSong', song='Camera Talk'),
#  Row(ts=1540999812000, page='NextSong', song='The Sicilian'),
#  Row(ts=1541000072000, page='NextSong', song='Pursuit Of Happiness (nightmare)'),
#  Row(ts=1541000367000, page='NextSong', song='Basbhat (Album Version)'),
#  Row(ts=1541000528000, page='NextSong', song='The Pretender'),
#  Row(ts=1541000594000, page='Roll Advert', song=None),
#  Row(ts=1541000604000, page='Roll Advert', song=None),
#  Row(ts=1541000799000, page='NextSong', song='Movement'),
#  Row(ts=1541000982000, page='NextSong', song='Revelry'),
#  Row(ts=1541001183000, page='NextSong', song='My Last Serenade'),
#  Row(ts=1541001436000, page='NextSong', song='Her Alone'),
#  Row(ts=1541001797000, page='NextSong', song='Diva'),
#  Row(ts=1541001815000, page='Roll Advert', song=None),
#  Row(ts=1541002054000, page='NextSong', song='Inhuman Creation Station'),
#  Row(ts=1541002303000, page='NextSong', song='Monster (Alternate Radio Version)'),
#  Row(ts=1541002480000, page='NextSong', song='The Game (Amended Version)'),
#  Row(ts=1541002706000, page='NextSong', song='Keep It Simple'),
#  Row(ts=1541002981000, page='NextSong', song='No Leaf Clover'),
#  Row(ts=1541003324000, page='NextSong', song='Tramazi Parti'),
#  Row(ts=1541003609000, page='NextSong', song='My Way (A Mi Manera) (Album Version)'),
#  Row(ts=1541003713000, page='NextSong', song='Horrorbeach (Album Version)'),
#  Row(ts=1541003885000, page='NextSong', song='Red Light Indicates Doors Are Secured'),
#  Row(ts=1541004028000, page='NextSong', song='Girl'),
#  Row(ts=1541004043000, page='Upgrade', song=None),
#  Row(ts=1541004239000, page='NextSong', song="Don't Worry Be Happy"),
#  Row(ts=1541004530000, page='NextSong', song='Splash'),
#  Row(ts=1541004772000, page='NextSong', song='Missing You'),
#  Row(ts=1541005041000, page='NextSong', song='Goodbye Is All We Have'),
#  Row(ts=1541005273000, page='NextSong', song='Raunioilla'),
#  Row(ts=1541006089000, page='NextSong', song='Time/Breathe [Reprise] (Album Version)'),
#  Row(ts=1541006385000, page='NextSong', song='Magic Mountain'),
#  Row(ts=1541006567000, page='NextSong', song='Take The Box'),
#  Row(ts=1541006767000, page='NextSong', song="O Ouranos Pano Ap' ton Grammo"),
#  Row(ts=1541006779000, page='Add to Playlist', song=None),
#  Row(ts=1541006834000, page='NextSong', song="Boys Don't Cry"),
#  Row(ts=1541006835000, page='Thumbs Down', song=None),
#  Row(ts=1541006995000, page='NextSong', song='Precious Memories (LP Version)'),
#  Row(ts=1541006996000, page='Thumbs Up', song=None),
#  Row(ts=1541007248000, page='NextSong', song='Path'),
#  Row(ts=1541007451000, page='NextSong', song='The Scientist'),
#  Row(ts=1541007452000, page='Logout', song=None),
#  Row(ts=1541007500000, page='Home', song=None),
#  Row(ts=1541007762000, page='NextSong', song='Rock Star'),
#  Row(ts=1541008021000, page='NextSong', song='Palm Reader'),
#  Row(ts=1541008314000, page='NextSong', song='Para Bellum'),
#  Row(ts=1541008399000, page='NextSong', song="Maggie's Farm"),
#  Row(ts=1541008794000, page='NextSong', song='Four Winds'),
#  Row(ts=1541008829000, page='Roll Advert', song=None),
#  Row(ts=1541009029000, page='NextSong', song='Fight'),
#  Row(ts=1541009041000, page='Roll Advert', song=None),
#  Row(ts=1541041139000, page='NextSong', song='Things She Said'),
#  Row(ts=1541041436000, page='NextSong', song='Sehr kosmisch'),
#  Row(ts=1541042091000, page='NextSong', song='Sin Coro'),
#  Row(ts=1541042319000, page='NextSong', song='Not In Love'),
#  Row(ts=1541042532000, page='NextSong', song='Miserable Lie'),
#  Row(ts=1541042799000, page='NextSong', song='Scooby Snacks (Explicit)'),
#  Row(ts=1541042983000, page='NextSong', song='Him'),
#  Row(ts=1541043180000, page='NextSong', song='Diary'),
#  Row(ts=1541043464000, page='NextSong', song='Opening Up (Ce Soir On Danse)'),
#  Row(ts=1541043764000, page='NextSong', song='Guiding Light'),
#  Row(ts=1541044017000, page='NextSong', song='La Guerra'),
#  Row(ts=1541044533000, page='NextSong', song='Oh Girl'),
#  Row(ts=1541044713000, page='NextSong', song="Bottle Poppin' (feat. Gorilla Zoe) (Explicit Album Version)"),
#  Row(ts=1541044761000, page='Roll Advert', song=None),
#  Row(ts=1541045012000, page='NextSong', song='Einfeld'),
#  Row(ts=1541045013000, page='Logout', song=None),
#  Row(ts=1541045078000, page='Home', song=None),
#  Row(ts=1541045327000, page='NextSong', song="I'm With You"),
#  Row(ts=1541045342000, page='Settings', song=None),
#  Row(ts=1541045549000, page='NextSong', song='Machine Gun Man'),
#  Row(ts=1541045846000, page='NextSong', song='I Want It All'),
#  Row(ts=1541046123000, page='NextSong', song='Straight To The Bank'),
#  Row(ts=1541046316000, page='NextSong', song='Rock On'),
#  Row(ts=1541046480000, page='NextSong', song='This Is All I Ask (Live)'),
#  Row(ts=1541047038000, page='NextSong', song='Woman Tonight'),
#  Row(ts=1541047186000, page='NextSong', song='Dialogue'),
#  Row(ts=1541047238000, page='NextSong', song='No Child Of Mine'),
#  Row(ts=1541047271000, page='Upgrade', song=None),
# ...
#  Row(ts=1541047894000, page='Help', song=None),
#  Row(ts=1541047925000, page='Home', song=None),
#  Row(ts=1541048045000, page='NextSong', song='Something (Album Version)'),
#  Row(ts=1541048245000, page='NextSong', song='Will I See You Again'),
#  Row(ts=1541048424000, page='NextSong', song='Two Hands (Plastic Soul Impalement Album Version)'),
#  Row(ts=1541048646000, page='NextSong', song='Cut The Rope'),
#  Row(ts=1541048755000, page='NextSong', song='A Comet Appears (Album)'),
#  Row(ts=1541048756000, page='Thumbs Up', song=None),
#  Row(ts=1541048984000, page='NextSong', song='The Power Of One'),
#  Row(ts=1541048991000, page='Roll Advert', song=None),
#  Row(ts=1541049676000, page='NextSong', song='Being Alive'),
#  Row(ts=1541049982000, page='NextSong', song='Technologic ( Basement Jaxx Kontrol Mixx )'),
#  Row(ts=1541049983000, page='Add Friend', song=None),
#  Row(ts=1541050313000, page='NextSong', song='Back To You'),
#  Row(ts=1541050554000, page='NextSong', song='Ironic (Acoustic Album Version)'),
#  Row(ts=1541050583000, page='Add to Playlist', song=None),
#  Row(ts=1541050790000, page='NextSong', song='All I Ever Wanted'),
#  Row(ts=1541051029000, page='NextSong', song='Better in time'),
#  Row(ts=1541051036000, page='Roll Advert', song=None),
#  Row(ts=1541051262000, page='NextSong', song='One Above One'),
#  Row(ts=1541051483000, page='NextSong', song='Crank That (Soulja Boy)'),
#  Row(ts=1541051707000, page='NextSong', song='Du Hast'),
#  Row(ts=1541051977000, page='NextSong', song='Confetti Smile (AO Album Version)'),
#  Row(ts=1541052199000, page='NextSong', song='Vem Pra CÃ\x83Â¡'),
#  Row(ts=1541052456000, page='NextSong', song='True Stories'),
#  Row(ts=1541052625000, page='NextSong', song='Dr. Feelgood'),
#  Row(ts=1541052908000, page='NextSong', song='The Writer'),
#  Row(ts=1541053159000, page='NextSong', song='Ass Fucking Murder'),
#  Row(ts=1541053177000, page='Home', song=None),
#  Row(ts=1541053366000, page='NextSong', song="All Tomorrow's Parties"),
#  Row(ts=1541053726000, page='NextSong', song='Ocean Avenue'),
#  Row(ts=1541053924000, page='NextSong', song='Venus'),
#  Row(ts=1541053925000, page='Thumbs Up', song=None),
#  Row(ts=1541053945000, page='Add to Playlist', song=None),
#  Row(ts=1541054168000, page='NextSong', song='Learn To Fly'),
#  Row(ts=1541054403000, page='NextSong', song='Touchy! (Album Version)'),
#  Row(ts=1541054680000, page='NextSong', song='Jude Law and a Semester Abroad'),
#  Row(ts=1541054900000, page='NextSong', song='Dream On'),
#  Row(ts=1541055194000, page='NextSong', song='Half Asleep'),
#  Row(ts=1541055465000, page='NextSong', song='MatinÃ\x83Â©e'),
#  Row(ts=1541055703000, page='NextSong', song='Mysterious Ways'),
#  Row(ts=1541055952000, page='NextSong', song='Peaceful'),
#  Row(ts=1541056124000, page='NextSong', song='Otherside (Album Version)'),
#  Row(ts=1541056379000, page='NextSong', song='Bad Little Woman (LP Version)'),
#  Row(ts=1541169777000, page='NextSong', song='Superman'),
#  Row(ts=1541170127000, page='NextSong', song='Intro 2/ Kick Out The Jams (LP Version)'),
#  Row(ts=1541170299000, page='NextSong', song='Dance Flow'),
#  Row(ts=1541170756000, page='NextSong', song='Hey Now Now'),
#  Row(ts=1541170966000, page='NextSong', song='Save The Last Dance For Me [Ralphi Rosario Anthomic Vocal]'),
#  Row(ts=1541170967000, page='Thumbs Up', song=None),
#  Row(ts=1541171542000, page='NextSong', song='MÃ\x83Â¡s Papaya'),
#  Row(ts=1541171756000, page='NextSong', song='Dialogue Box'),
#  Row(ts=1541171990000, page='NextSong', song='The Ex'),
#  Row(ts=1541172150000, page='NextSong', song='Crack Under Pressure'),
#  Row(ts=1541172208000, page='Add to Playlist', song=None),
#  Row(ts=1541172353000, page='NextSong', song='Odessa'),
#  Row(ts=1541172668000, page='NextSong', song='Addicted'),
#  Row(ts=1541172833000, page='NextSong', song='DVNO'),
#  Row(ts=1541173069000, page='NextSong', song='Bad Luck'),
#  Row(ts=1541173240000, page='NextSong', song="Rupi's Dance"),
#  Row(ts=1541173242000, page='Home', song=None),
#  Row(ts=1541173420000, page='NextSong', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(ts=1541173697000, page='NextSong', song='Safety Dance'),
#  Row(ts=1541173861000, page='NextSong', song="Build God_ Then We'll Talk (Album Version)"),
#  Row(ts=1541174081000, page='NextSong', song='ReprÃ\x83Â©sente'),
#  Row(ts=1541174333000, page='NextSong', song="I CAN'T GET STARTED"),
#  Row(ts=1541174830000, page='NextSong', song='What A Wonderful World'),
#  Row(ts=1541175011000, page='NextSong', song='Not Like That (Album Version)'),
#  Row(ts=1541175192000, page='NextSong', song='So far so long'),
#  Row(ts=1541175365000, page='NextSong', song='En El Septimo Dia'),
#  Row(ts=1541175660000, page='NextSong', song='Let Down'),
#  Row(ts=1541175958000, page='NextSong', song='Pon De Floor'),
#  Row(ts=1541175995000, page='Upgrade', song=None),
#  Row(ts=1541176143000, page='NextSong', song='Hotel'),
#  Row(ts=1541176145000, page='Roll Advert', song=None),
#  Row(ts=1541202975000, page='NextSong', song='Gestern_Morgen'),
#  Row(ts=1541203331000, page='NextSong', song='Show'),
#  Row(ts=1541203597000, page='NextSong', song='Jasey Rae'),
#  Row(ts=1541203674000, page='Home', song=None),
#  Row(ts=1541203675000, page='Add Friend', song=None),
#  Row(ts=1541203676000, page='Add Friend', song=None),
#  Row(ts=1541203814000, page='NextSong', song='Sooner or Later'),
#  Row(ts=1541204215000, page='NextSong', song='Good Soldier'),
#  Row(ts=1541204243000, page='Home', song=None),
#  Row(ts=1541204461000, page='NextSong', song='Soul Suckers'),
#  Row(ts=1541204491000, page='Add to Playlist', song=None),
#  Row(ts=1541204630000, page='NextSong', song='Seed (Album Version)'),
#  Row(ts=1541204887000, page='NextSong', song="Day 'N' Nite"),
#  Row(ts=1541205049000, page='NextSong', song='Climbing A Hill'),
#  Row(ts=1541205064000, page='Home', song=None),
#  Row(ts=1541205714000, page='NextSong', song='Ode To My Family'),
#  Row(ts=1541205986000, page='NextSong', song='Live And Let Die'),
#  Row(ts=1541206170000, page='NextSong', song="Livin' On A Prayer"),
#  Row(ts=1541206420000, page='NextSong', song='Good Morning Little School Girl'),
#  Row(ts=1541206582000, page='NextSong', song="Stayin' Alive"),
#  Row(ts=1541206820000, page='NextSong', song='Two As One'),
#  Row(ts=1541206821000, page='Add Friend', song=None),
#  Row(ts=1541207020000, page='NextSong', song='Big Uncle Ugliness'),
#  Row(ts=1541207264000, page='NextSong', song='Prelude'),
#  Row(ts=1541207282000, page='Upgrade', song=None),
#  Row(ts=1541207434000, page='NextSong', song='Transparency'),
#  Row(ts=1541207446000, page='Roll Advert', song=None),
#  Row(ts=1541207582000, page='NextSong', song='Behind Closed Doors'),
#  Row(ts=1541207777000, page='NextSong', song='Sample Track 2'),
#  Row(ts=1541207783000, page='Roll Advert', song=None),
#  Row(ts=1541207972000, page='NextSong', song='La Lluvia Gris'),
#  Row(ts=1541208235000, page='NextSong', song='Stream'),
#  Row(ts=1541208236000, page='Logout', song=None),
#  Row(ts=1541208254000, page='Home', song=None),
#  Row(ts=1541208424000, page='NextSong', song='Three Simple Words'),
#  Row(ts=1541208702000, page='NextSong', song='Fortunate Son (Live)'),
#  Row(ts=1541208905000, page='NextSong', song='Yeah!'),
#  Row(ts=1541209155000, page='NextSong', song='Mamma'),
#  Row(ts=1541209406000, page='NextSong', song='Venice Industry'),
#  Row(ts=1541209595000, page='NextSong', song='Nah!'),
#  Row(ts=1541209596000, page='Thumbs Down', song=None),
#  Row(ts=1541209845000, page='NextSong', song='ReprÃ\x83Â©sente'),
#  Row(ts=1541210097000, page='NextSong', song='Jiguen'),
#  Row(ts=1541210383000, page='NextSong', song='Ba Ba'),
#  Row(ts=1541210754000, page='NextSong', song='Superballs'),
#  Row(ts=1541210946000, page='NextSong', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(ts=1541210954000, page='Add to Playlist', song=None),
#  Row(ts=1541211223000, page='NextSong', song="You're The One"),
#  Row(ts=1541211462000, page='NextSong', song='Heartbeats'),
#  Row(ts=1541211620000, page='NextSong', song='Otherside (Album Version)'),
#  Row(ts=1541211875000, page='NextSong', song='Rio'),
#  Row(ts=1541211879000, page='Roll Advert', song=None),
#  Row(ts=1541212208000, page='NextSong', song='Plush (LP Version)'),
#  Row(ts=1541212518000, page='NextSong', song='First Of The Gang'),
#  Row(ts=1541212754000, page='NextSong', song='Me And Armini'),
#  Row(ts=1541213011000, page='NextSong', song='Traveller'),
#  Row(ts=1541213687000, page='NextSong', song='Sweet Carrie'),
#  Row(ts=1541213688000, page='Thumbs Up', song=None),
#  Row(ts=1541213973000, page='NextSong', song='Sick_ Sick_ Sick'),
#  Row(ts=1541214187000, page='NextSong', song='The Blast'),
#  Row(ts=1541214411000, page='NextSong', song='Beautiful Stranger'),
#  Row(ts=1541214671000, page='NextSong', song='No Milk Today'),
#  Row(ts=1541214857000, page='NextSong', song='Repression Song'),
#  Row(ts=1541215028000, page='NextSong', song='Non E_ Per Te_ Per Me'),
#  Row(ts=1541215258000, page='NextSong', song="What's The Difference"),
#  Row(ts=1541215502000, page='NextSong', song='Restless'),
#  Row(ts=1541215673000, page='NextSong', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(ts=1541215950000, page='NextSong', song='Teardrop'),
#  Row(ts=1541216279000, page='NextSong', song='Seven'),
#  Row(ts=1541216637000, page='NextSong', song='Gone In The Morning'),
#  Row(ts=1541216778000, page='NextSong', song='Baby_ This Love I Have'),
#  Row(ts=1541217028000, page='NextSong', song='Me Da Miedo'),
#  Row(ts=1541217193000, page='NextSong', song='I Can See Clearly Now'),
#  Row(ts=1541217381000, page='NextSong', song='Nemo'),
#  Row(ts=1541217646000, page='NextSong', song='Choctaw Hayride'),
#  Row(ts=1541217836000, page='NextSong', song='The Real Slim Shady'),
#  Row(ts=1541218120000, page='NextSong', song='Silence'),
#  Row(ts=1541218614000, page='NextSong', song='Snake'),
#  Row(ts=1541218617000, page='About', song=None),
#  Row(ts=1541218903000, page='NextSong', song='Your Hand In Mine'),
#  Row(ts=1541218904000, page='Logout', song=None),
#  Row(ts=1541218934000, page='Home', song=None),
#  Row(ts=1541219400000, page='NextSong', song='Marry Me'),
#  Row(ts=1541219401000, page='Thumbs Up', song=None),
#  Row(ts=1541219605000, page='NextSong', song='Undo'),
#  Row(ts=1541219622000, page='Upgrade', song=None),
#  Row(ts=1541219953000, page='NextSong', song='Use Somebody'),
#  Row(ts=1541220184000, page='NextSong', song="Can't You See"),
#  Row(ts=1541220546000, page='NextSong', song='Skinny Love'),
#  Row(ts=1541220784000, page='NextSong', song='All We Ever Do Is Say Goodbye'),
#  Row(ts=1541221059000, page='NextSong', song='Amanecer'),
#  Row(ts=1541221060000, page='Roll Advert', song=None),
#  Row(ts=1541221287000, page='NextSong', song='Starry Night'),
#  Row(ts=1541221485000, page='NextSong', song='Unwell (Album Version)'),
#  Row(ts=1541221714000, page='NextSong', song='West One (Shine On Me)'),
#  Row(ts=1541221734000, page='Roll Advert', song=None),
#  Row(ts=1541222052000, page='NextSong', song='Ironic (Acoustic Album Version)'),
#  Row(ts=1541314757000, page='NextSong', song="You've Got The Love"),
#  Row(ts=1541314766000, page='Roll Advert', song=None),
#  Row(ts=1541314925000, page='NextSong', song='Innocence'),
#  Row(ts=1541315241000, page='NextSong', song='Las flores'),
#  Row(ts=1541315376000, page='NextSong', song='Longhaired Redneck'),
#  Row(ts=1541315407000, page='Home', song=None),
#  Row(ts=1541315579000, page='NextSong', song="Don't Come Around Here No More"),
#  Row(ts=1541315886000, page='NextSong', song='Love Story'),
#  Row(ts=1541315897000, page='Roll Advert', song=None),
#  Row(ts=1541316119000, page='NextSong', song='The Message'),
#  Row(ts=1541316548000, page='NextSong', song='Beautiful Stranger'),
#  Row(ts=1541316808000, page='NextSong', song='White Noise'),
#  Row(ts=1541317039000, page='NextSong', song='Home'),
#  Row(ts=1541317323000, page='NextSong', song='Cry Baby'),
#  Row(ts=1541317677000, page='NextSong', song='Vals fÃ\x83Â¶r satan (din vÃ\x83Â¤n pessimisten)'),
#  Row(ts=1541318084000, page='NextSong', song='If She Wants Me'),
#  Row(ts=1541318389000, page='NextSong', song='Behind The Sea [Live In Chicago]'),
#  Row(ts=1541318648000, page='NextSong', song='Complex Person'),
#  Row(ts=1541318815000, page='NextSong', song='Better'),
#  Row(ts=1541319005000, page='NextSong', song='Hallelujah (Album Version)'),
#  Row(ts=1541319208000, page='NextSong', song='You Girl'),
#  Row(ts=1541319435000, page='NextSong', song='No BalanÃ\x83Â§o Da Canoa'),
#  Row(ts=1541319443000, page='Add to Playlist', song=None),
#  Row(ts=1541319612000, page='NextSong', song='The Drive System (Demo)'),
#  Row(ts=1541319779000, page='NextSong', song='Kick It Up'),
#  Row(ts=1541320077000, page='NextSong', song='Bombtrack'),
#  Row(ts=1541320092000, page='Home', song=None),
#  Row(ts=1541320093000, page='Add Friend', song=None),
#  Row(ts=1541320322000, page='NextSong', song="I'm With You"),
#  Row(ts=1541320323000, page='Thumbs Up', song=None),
#  Row(ts=1541320544000, page='NextSong', song='Pills'),
#  Row(ts=1541320800000, page='NextSong', song='The Seed (2.0)'),
#  Row(ts=1541321067000, page='NextSong', song='The Count (aka HervÃ\x83Â©) And Lily Face The Fear'),
#  Row(ts=1541321068000, page='Thumbs Up', song=None),
#  Row(ts=1541321328000, page='NextSong', song="Don't Dream It's Over"),
#  Row(ts=1541421195000, page='NextSong', song='The Alliance Of Hellhoundz'),
#  Row(ts=1541421514000, page='NextSong', song='What If I Stumble?'),
#  Row(ts=1541421819000, page='NextSong', song="I'll Be There For You"),
#  Row(ts=1541422008000, page='NextSong', song='Somebody To Love'),
#  Row(ts=1541422228000, page='NextSong', song='Use Somebody'),
#  Row(ts=1541422459000, page='NextSong', song='Too Much To Ask'),
#  Row(ts=1541422511000, page='Add to Playlist', song=None),
#  Row(ts=1541422684000, page='NextSong', song='Gears'),
#  Row(ts=1541422923000, page='NextSong', song='Dog Days Are Over (Radio Edit)'),
#  Row(ts=1541423142000, page='NextSong', song="Dreamin'"),
#  Row(ts=1541423315000, page='NextSong', song='Inside The Fire (Album Version)'),
#  Row(ts=1541423324000, page='Roll Advert', song=None),
#  Row(ts=1541423328000, page='Roll Advert', song=None),
#  Row(ts=1541423546000, page='NextSong', song='Fakty'),
#  Row(ts=1541423670000, page='NextSong', song='Jambalaya'),
#  Row(ts=1541423709000, page='Upgrade', song=None),
#  Row(ts=1541423891000, page='NextSong', song='The Shadowlands'),
#  Row(ts=1541423892000, page='Logout', song=None),
#  Row(ts=1541423920000, page='Home', song=None),
#  Row(ts=1541424209000, page='NextSong', song='The Invisible Man'),
#  Row(ts=1541424510000, page='NextSong', song='Firecracker'),
#  Row(ts=1541424718000, page='NextSong', song='Bleed It Out [Live At Milton Keynes]'),
#  Row(ts=1541425212000, page='NextSong', song='Miralo'),
#  Row(ts=1541425403000, page='NextSong', song='ReprÃ\x83Â©sente'),
#  Row(ts=1541425655000, page='NextSong', song='Silencio'),
#  Row(ts=1541425700000, page='Roll Advert', song=None),
#  Row(ts=1541425944000, page='NextSong', song='Momma Cried'),
#  Row(ts=1541425989000, page='Roll Advert', song=None),
#  Row(ts=1541430348000, page='NextSong', song='La Vida Es Un Ratico'),
#  Row(ts=1541430349000, page='Thumbs Down', song=None),
#  Row(ts=1541430591000, page='NextSong', song='Cape Cod Kwassa Kwassa (Album)'),
#  Row(ts=1541430805000, page='NextSong', song='Write You A Song'),
#  Row(ts=1541431046000, page='NextSong', song='Elijah'),
#  Row(ts=1541431190000, page='NextSong', song='Fireflies'),
#  Row(ts=1541431191000, page='Thumbs Up', song=None),
#  Row(ts=1541431415000, page='NextSong', song="You Don't Have Far To Go"),
#  Row(ts=1541442785000, page='NextSong', song='One by One'),
#  Row(ts=1541442990000, page='NextSong', song='Wasted'),
#  Row(ts=1541443162000, page='NextSong', song='Me Voy'),
#  Row(ts=1541443425000, page='NextSong', song='Dear God (Album Version)'),
#  Row(ts=1541443818000, page='NextSong', song='Die Hard'),
#  Row(ts=1541443819000, page='Thumbs Up', song=None),
#  Row(ts=1541443875000, page='NextSong', song='When The Stars Go Blue (Featuring Bono) (Disclab Remix)'),
#  Row(ts=1541444113000, page='NextSong', song='What Can I Give You This Christmas?'),
#  ...]

# %%
# filter out missing user ids
user_log_valid = user_log.dropna(how = "any", subset = ["userId", "sessionId"])
user_log_valid = user_log_valid.filter(user_log_valid["userId"] != "")
user_log_valid.count()
# Out:
# 278154

# %% [markdown]
# # Exploratory Data Analysis
# When you're working with the full dataset, perform EDA by loading a small subset of the data and doing basic manipulations within Spark. In this workspace, you are already provided a small subset of data you can explore.
#
# ### Define Churn
#
# Once you've done some preliminary analysis, create a column `Churn` to use as the label for your model. I suggest using the `Cancellation Confirmation` events to define your churn, which happen for both paid and free users. As a bonus task, you can also look into the `Downgrade` events.
#
# ### Explore Data
# Once you've defined churn, perform some exploratory data analysis to observe the behavior for users who stayed vs users who churned. You can start by exploring aggregates on these two groups of users, observing how much of a specific action they experienced per a certain time unit or number of songs played.

# %%
# flag events of interest beginning with churn
# I chose to name my column "churn_flag" instead of "Churn"

flag_churn_event = udf(lambda x: 1 if x == "Cancellation Confirmation" else 0, IntegerType())
flag_up_event = udf(lambda x: 1 if x == "Thumbs Up" else 0, IntegerType())
flag_down_event = udf(lambda x: 1 if x == "Thumbs Down" else 0, IntegerType())
flag_listen_event = udf(lambda x: 1 if x == "NextSong" else 0, IntegerType())
flag_playlist_event = udf(lambda x: 1 if x == "Add to Playlist" else 0, IntegerType())

user_log_valid = user_log_valid.withColumn("churn_flag", flag_churn_event("page"))
user_log_valid = user_log_valid.withColumn("up_flag", flag_up_event("page"))
user_log_valid = user_log_valid.withColumn("down_flag", flag_down_event("page"))
user_log_valid = user_log_valid.withColumn("listen_flag", flag_listen_event("page"))
user_log_valid = user_log_valid.withColumn("playlist_flag", flag_playlist_event("page"))

# %%
# verify new columns exist as expected
user_log_valid.head()
# Out:
# Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30', churn_flag=0, up_flag=0, down_flag=0, listen_flag=1, playlist_flag=0)

# %%
# -----add a column to identify whether each user in the dataset ever churns at any point-----
# create a dataset of just users who churned and then join the full dataset to this churn dataset
# resulting in a new column, "ever_churns", that can be used for aggregation

churned_users = user_log_valid.select(["userId","churn_flag"]).where(user_log_valid.churn_flag == 1)
churned_users = churned_users.withColumnRenamed("userId", "userId_churned").withColumnRenamed("churn_flag", "ever_churns")
user_log_joined2 = user_log_valid.join(churned_users,user_log_valid.userId ==  churned_users.userId_churned,"left")

# %%
# compare how many users churn vs do not churn
user_log_joined2.groupby("ever_churns").count().show()
# Out:
# +-----------+------+
# |ever_churns| count|
# +-----------+------+
# |       null|233290|
# |          1| 44864|
# +-----------+------+

# %%
# compare the playlist actions of each group
user_log_joined2.groupby("ever_churns").mean("playlist_flag").show()
# Out:
# +-----------+--------------------+
# |ever_churns|  avg(playlist_flag)|
# +-----------+--------------------+
# |       null|0.023524368811350678|
# |          1|0.023136590584878745|
# +-----------+--------------------+

# %%
# compare the listening actions of each group
user_log_joined2.groupby("ever_churns").mean("listen_flag").show()
# Out:
# +-----------+------------------+
# |ever_churns|  avg(listen_flag)|
# +-----------+------------------+
# |       null|0.8217840456084702|
# |          1|0.8112072039942939|
# +-----------+------------------+

# %%
# compare the thumbs-up actions of each group
user_log_joined2.groupby("ever_churns").mean("up_flag").show()
# Out:
# +-----------+-------------------+
# |ever_churns|       avg(up_flag)|
# +-----------+-------------------+
# |       null|0.04583136868275537|
# |          1|0.04143634094151213|
# +-----------+-------------------+

# %%
# compare the thumbs-down actions of each group
user_log_joined2.groupby("ever_churns").mean("down_flag").show()
# Out:
# +-----------+--------------------+
# |ever_churns|      avg(down_flag)|
# +-----------+--------------------+
# |       null|0.008787346221441126|
# |          1|0.011055634807417974|
# +-----------+--------------------+

# %%
# thumbs-down actions appear to be notably different between the groups.

# create a dataframe of aggregate data about each user.
# the new dataframe should have the total count of each event and the churn status of each user

# %%
# total count of each event per user
metaDf1 = user_log_valid.groupby("userid").sum("up_flag", "down_flag", "listen_flag", "playlist_flag")

# %%
# churn status of each user
metaDf2 = user_log_valid.groupby("userid").max("churn_flag").withColumnRenamed("userId", "userId_dup")

# %%
# combine the two dataframes of metadata
metaDf = metaDf1.join(metaDf2, metaDf1.userid == metaDf2.userId_dup).drop("userId_dup")

# %%
# view the results
metaDf.show()
# Out:
# +------+------------+--------------+----------------+------------------+---------------+
# |userid|sum(up_flag)|sum(down_flag)|sum(listen_flag)|sum(playlist_flag)|max(churn_flag)|
# +------+------------+--------------+----------------+------------------+---------------+
# |100010|          17|             5|             275|                 7|              0|
# |200002|          21|             6|             387|                 8|              0|
# |   125|           0|             0|               8|                 0|              1|
# |   124|         171|            41|            4079|               118|              0|
# |    51|         100|            21|            2111|                52|              1|
# |     7|           7|             1|             150|                 5|              0|
# |    15|          81|            14|            1914|                59|              0|
# |    54|         163|            29|            2841|                72|              1|
# |   155|          58|             3|             820|                24|              0|
# |100014|          17|             3|             257|                 7|              1|
# |   132|          96|            17|            1928|                38|              0|
# |   154|          11|             0|              84|                 1|              0|
# |   101|          86|            16|            1797|                61|              1|
# |    11|          40|             9|             647|                20|              0|
# |   138|          95|            24|            2070|                67|              0|
# |300017|         303|            28|            3632|               113|              0|
# |100021|          11|             5|             230|                 7|              1|
# |    29|         154|            22|            3028|                89|              1|
# |    69|          72|             9|            1125|                33|              0|
# |   112|           9|             3|             215|                 7|              0|
# +------+------------+--------------+----------------+------------------+---------------+
# only showing top 20 rows

# %% [markdown]
# # Feature Engineering
# Once you've familiarized yourself with the data, build out the features you find promising to train your model on. To work with the full dataset, you can follow the following steps.
# - Write a script to extract the necessary features from the smaller subset of data
# - Ensure that your script is scalable, using the best practices discussed in Lesson 3
# - Try your script on the full data set, debugging your script if necessary
#
# If you are working in the classroom workspace, you can just extract features based on the small subset of data contained here. Be sure to transfer over this work to the larger dataset when you work on your Spark cluster.

# %% [markdown]
# ### Early Attempts that Failed
# I tried various approaches before deciding on my final feature set. I show them at the end of the Notebook for completeness and to solicit feedback on the ideas.

# %% [markdown]
# ### Feature Choice

# %%
# vectorize the data features
assembler = VectorAssembler(inputCols=["sum(up_flag)", "sum(down_flag)", "sum(listen_flag)", "sum(playlist_flag)"], outputCol="FeaturesVector")
metaDf = assembler.transform(metaDf)

# normalize the now vectorized features using Normalizer
# Normalizer operates row-wise, scaling each row so that its norm equals 1
scaler = Normalizer(inputCol="FeaturesVector", outputCol="ScaledNumFeatures")
metaDf = scaler.transform(metaDf)

# also try using StandardScaler on the feature vector as a second option to test
# StandardScaler operates column-wise to remove the mean and scale to unit variance
scaler2 = StandardScaler(inputCol="FeaturesVector", outputCol="ScaledNumFeatures2", withStd=True)
scalerModel = scaler2.fit(metaDf)
metaDf = scalerModel.transform(metaDf)

# %%
# view the results
metaDf.head()
# Out:
# Row(userid='100010', sum(up_flag)=17, sum(down_flag)=5, sum(listen_flag)=275, sum(playlist_flag)=7, max(churn_flag)=0, FeaturesVector=DenseVector([17.0, 5.0, 275.0, 7.0]), ScaledNumFeatures=DenseVector([0.0617, 0.0181, 0.9976, 0.0254]), ScaledNumFeatures2=DenseVector([0.2596, 0.3823, 0.2489, 0.214]))

# %% [markdown]
# # Modeling
# Split the full dataset into train, test, and validation sets. Test out several of the machine learning methods you learned. Evaluate the accuracy of the various models, tuning parameters as necessary. Determine your winning model based on test accuracy and report results on the validation set. Since the churned users are a fairly small subset, I suggest using F1 score as the metric to optimize.

# %%
# split the data set into train and test sets (7:3)
# CrossValidator negates the need for a validation set as this function is built-in

train, test = metaDf.randomSplit([0.7, 0.3], seed=42)

# %%
# build, train, and test a Logistic Regression model

# in order to prevent overfitting, I choose a regularization paramter of zero
# I aslo set elasticNetParam to zero so penalties will not be combined when I introduce regParam = 0.1 in my Pipeline
lr =  LogisticRegression(maxIter=10, regParam=0.0, elasticNetParam=0)

# build pipeline
lrPipeline = Pipeline(stages=[lr])

# add regParam value of 0.1 to be tested
lrParamGrid = ParamGridBuilder() \
    .addGrid(lr.regParam,[0.0, 0.1]) \
    .build()

# build CrossValidator with 3 folds
lrCrossval = CrossValidator(estimator=lrPipeline,
                          estimatorParamMaps=lrParamGrid,
                          evaluator=BinaryClassificationEvaluator(),
                          numFolds=3)

# train model on Normalizer feature vector
lrModel1 = lrCrossval.fit(train.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures").alias("features")))
# train model on StandardScaler feature vector
lrModel2 = lrCrossval.fit(train.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures2").alias("features")))

# test both models
lrResults1 = lrModel1.transform(test.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures").alias("features")))
lrResults2 = lrModel2.transform(test.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures2").alias("features")))

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(lrModel1.avgMetrics)
print(lrResults1.filter(lrResults1.label == lrResults1.prediction).count())
print(lrResults1.count())
# Out:
# [0.6726159469635807, 0.6726159469635807]
# 46
# 62

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(lrModel2.avgMetrics)
print(lrResults2.filter(lrResults2.label == lrResults2.prediction).count())
print(lrResults2.count())
# Out:
# [0.6640595419454332, 0.6640547447048994]
# 46
# 62

# %%
# build, train, and test a Random Forest model

rf = RandomForestClassifier(featuresCol = 'features', labelCol = 'label')

# build pipeline
rfPipeline = Pipeline(stages=[rf])

# set values of both 3 and 10 to be tested for the number of trees to build before averaging the trees' predictions
# I choose two low values in order to spare processing burden. If 10 performs better than 3, I could try higher values.
rfParamGrid = ParamGridBuilder() \
    .addGrid(rf.numTrees, [10, 100]) \
    .build()

# build CrossValidator with 3 folds
rfCrossval = CrossValidator(
    estimator=rfPipeline,
    estimatorParamMaps=rfParamGrid,
    evaluator=BinaryClassificationEvaluator(),
    numFolds=3)

# train model on Normalizer feature vector
rfModel1 = rfCrossval.fit(train.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures").alias("features")))
# train model on StandardScaler feature vector
rfModel2 = rfCrossval.fit(train.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures2").alias("features")))

# test both models
rfResults1 = rfModel1.transform(test.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures").alias("features")))
rfResults2 = rfModel2.transform(test.select(col("max(churn_flag)").alias("label"), col("ScaledNumFeatures2").alias("features")))

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(rfModel1.avgMetrics)
print(rfResults1.filter(rfResults1.label == rfResults1.prediction).count())
print(rfResults1.count())
# Out:
# [0.6010086490736646, 0.622668073077184]
# 45
# 62

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(rfModel2.avgMetrics)
print(rfResults2.filter(rfResults2.label == rfResults2.prediction).count())
print(rfResults2.count())
# Out:
# [0.6734975569175038, 0.6574074951618074]
# 45
# 62

# %% [markdown]
# # Final Steps
# Clean up your code, adding comments and renaming variables to make the code easier to read and maintain. Refer to the Spark Project Overview page and Data Scientist Capstone Project Rubric to make sure you are including all components of the capstone project and meet all expectations. Remember, this includes thorough documentation in a README file in a Github repository, as well as a web app or blog post.

# %% [markdown]
# See <a href="https://carrie-kruppa.medium.com/if-i-can-do-ml-in-spark-so-can-you-e32a7b56275c">blog post</a> on Medium for further discussion of this project.

# %% [markdown]
# ### Early Attempts that Failed
# I tried various approaches before deciding on my final feature set. I show them here for completeness and to solicit feedback on the ideas.

# %%
# At first I tried to turn the various pages a user could visit into dummy
# columns using code I didn't really understand. 
# The code worked, but I opted not to use it because I didn't grasp it.

"""
from pyspark.sql.functions import when
from pyspark.sql.functions import col

pages = user_log_valid.select("page").distinct().rdd.flatMap(lambda x: x).collect()
pages_expr = [when(col("page") == pg, 1).otherwise(0).alias("PAGE_" + pg) for pg in pages]
user_log_dummies = user_log_valid.select("page", *pages_expr)
user_log_dummies.show()
"""
# Out:
# '\nfrom pyspark.sql.functions import when\nfrom pyspark.sql.functions import col\n\npages = user_log_valid.select("page").distinct().rdd.flatMap(lambda x: x).collect()\npages_expr = [when(col("page") == pg, 1).otherwise(0).alias("PAGE_" + pg) for pg in pages]\nuser_log_dummies = user_log_valid.select("page", *pages_expr)\nuser_log_dummies.show()\n'

# %%
# Next, I wanted to create a running total of how many of each event a user has had up to the current date
# I wanted to use this for prediction modeling, i.e., identifying when a user's positive activity is slowing down
# I successfully created the features, but I couldn't figure out how to build a model based on the features

from pyspark.sql import Window
from pyspark.sql.functions import sum as Fsum

windowval = Window.partitionBy("userId").orderBy(desc("ts")).rangeBetween(Window.unboundedPreceding, 0)
user_log_valid = user_log_valid.withColumn("songs_to_date", Fsum("listen_flag").over(windowval))
user_log_valid = user_log_valid.withColumn("thumbsup_to_date", Fsum("up_flag").over(windowval))
user_log_valid = user_log_valid.withColumn("thumbsdown_to_date", Fsum("down_flag").over(windowval))
user_log_valid = user_log_valid.withColumn("pladds_to_date", Fsum("playlist_flag").over(windowval))
# user_log_valid.select(["userId", "firstname", "ts", "page", "level", "phase"]).where(user_log.userId == "51").sort("ts").collect()

# %%
# vectorizing the features I just created
assembler = VectorAssembler(inputCols=["songs_to_date", "thumbsup_to_date", "thumbsdown_to_date", "pladds_to_date"], outputCol="FeaturesVector")
user_log_valid = assembler.transform(user_log_valid)

# normalize feature vector row-wise
scaler = Normalizer(inputCol="FeaturesVector", outputCol="ScaledNumFeatures")
user_log_valid = scaler.transform(user_log_valid)

# normalize the features column-wise as a second option to test
scaler2 = StandardScaler(inputCol="FeaturesVector", outputCol="ScaledNumFeatures2", withStd=True)
scalerModel = scaler2.fit(user_log_valid)
user_log_valid = scalerModel.transform(user_log_valid)

# %%
# Still thinking along the lines of predicting a downward trend of events for each user based on running totals...
# I set out to create the label to go with my feature set.
# I decided to add a column to the data that indicates if a user is going to churn at any point in the next 7 days.
# My thinking is I could train a model to trend a user's events & predict if they would churn in the next week.
# I successfully created the label, but I couldn't figure out how to do the modeling. Too complex for me!

churn_users_dates = user_log_valid.select(["userId", "ts"]).where(user_log.page == "Cancellation Confirmation")
churn_users_dates = churn_users_dates.withColumnRenamed("ts", "churn_ts").withColumnRenamed("userId", "userId2")
user_log_joined = user_log_valid.join(churn_users_dates,user_log_valid.userId ==  churn_users_dates.userId2,"left")

def churnInNext3DaysF(x, y):
    if x is None:
        return 0
    if x - y < 0:
        return 0
    if x - y < 259200000: # 604800000
        return 1
    return 0

churnInNext3Days = udf(churnInNext3DaysF, IntegerType())

user_log_joined = user_log_joined.withColumn('churnInNext3Days', churnInNext3Days('churn_ts', 'ts'))
user_log_joined.show(5)
# Out:
# +----------+---------+---------+------+-------------+---------+---------+-----+--------------------+------+-----------+-------------+---------+-------------------+------+-------------+--------------------+------+----------+-------+---------+-----------+-------------+-------------+----------------+------------------+--------------+--------------+-----------------+--------------------+-------+--------+----------------+
# |    artist|     auth|firstName|gender|itemInSession| lastName|   length|level|            location|method|       page| registration|sessionId|               song|status|           ts|           userAgent|userId|churn_flag|up_flag|down_flag|listen_flag|playlist_flag|songs_to_date|thumbsup_to_date|thumbsdown_to_date|pladds_to_date|FeaturesVector|ScaledNumFeatures|  ScaledNumFeatures2|userId2|churn_ts|churnInNext3Days|
# +----------+---------+---------+------+-------------+---------+---------+-----+--------------------+------+-----------+-------------+---------+-------------------+------+-------------+--------------------+------+----------+-------+---------+-----------+-------------+-------------+----------------+------------------+--------------+--------------+-----------------+--------------------+-------+--------+----------------+
# |      null|Logged In| Darianna|     F|           34|Carpenter|     null| free|Bridgeport-Stamfo...|   PUT|     Logout|1538016340000|      187|               null|   307|1542823952000|"Mozilla/5.0 (iPh...|100010|         0|      0|        0|          0|            0|            0|               0|                 0|             0|     (4,[],[])|        (4,[],[])|           (4,[],[])|   null|    null|               0|
# |Lily Allen|Logged In| Darianna|     F|           33|Carpenter|185.25995| free|Bridgeport-Stamfo...|   PUT|   NextSong|1538016340000|      187|                 22|   200|1542823951000|"Mozilla/5.0 (iPh...|100010|         0|      0|        0|          1|            0|            1|               0|                 0|             0| (4,[0],[1.0])|    (4,[0],[1.0])|(4,[0],[8.4195559...|   null|    null|               0|
# |John Waite|Logged In| Darianna|     F|           32|Carpenter|269.76608| free|Bridgeport-Stamfo...|   PUT|   NextSong|1538016340000|      187|        Missing You|   200|1542823682000|"Mozilla/5.0 (iPh...|100010|         0|      0|        0|          1|            0|            2|               0|                 0|             0| (4,[0],[2.0])|    (4,[0],[1.0])|(4,[0],[0.0016839...|   null|    null|               0|
# |   Hermano|Logged In| Darianna|     F|           31|Carpenter|115.90485| free|Bridgeport-Stamfo...|   PUT|   NextSong|1538016340000|      187|Letters From Madrid|   200|1542823567000|"Mozilla/5.0 (iPh...|100010|         0|      0|        0|          1|            0|            3|               0|                 0|             0| (4,[0],[3.0])|    (4,[0],[1.0])|(4,[0],[0.0025258...|   null|    null|               0|
# |      null|Logged In| Darianna|     F|           30|Carpenter|     null| free|Bridgeport-Stamfo...|   GET|Roll Advert|1538016340000|      187|               null|   200|1542823257000|"Mozilla/5.0 (iPh...|100010|         0|      0|        0|          0|            0|            3|               0|                 0|             0| (4,[0],[3.0])|    (4,[0],[1.0])|(4,[0],[0.0025258...|   null|    null|               0|
# +----------+---------+---------+------+-------------+---------+---------+-----+--------------------+------+-----------+-------------+---------+-------------------+------+-------------+--------------------+------+----------+-------+---------+-----------+-------------+-------------+----------------+------------------+--------------+--------------+-----------------+--------------------+-------+--------+----------------+
# only showing top 5 rows

# %%
# view entire transaction history of a user I know churned
# verify the field churnInNext3Days has a value of 0 at first and 1 at the end

user_log_joined.select(["page","ts","churnInNext3Days"]).where(user_log_joined.userId == "18").collect()
# Out:
# [Row(page='Home', ts=1538499917000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538499933000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538500208000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538500476000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538500654000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538500842000, churnInNext3Days=0),
#  Row(page='Settings', ts=1538500856000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538501009000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538501340000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538501587000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538501740000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538501984000, churnInNext3Days=0),
#  Row(page='Settings', ts=1538502021000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538502124000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538502356000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538502626000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538502928000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538503097000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538503298000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538503521000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538503702000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538503941000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538503942000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538504166000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538504390000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538504654000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538505044000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538505045000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538505098000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538505438000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538505646000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538506015000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538506324000, churnInNext3Days=0),
#  Row(page='Logout', ts=1538506325000, churnInNext3Days=0),
#  Row(page='Home', ts=1538506468000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538506519000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538506764000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538506956000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538506989000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538507272000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538507446000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538507644000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538507888000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538508543000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538508768000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538509002000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538509242000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538509447000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538509595000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538509761000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538509885000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538510122000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538510384000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538510648000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538510860000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538510861000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538511080000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538511198000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538511199000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538511375000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538511583000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538512085000, churnInNext3Days=0),
#  Row(page='Add Friend', ts=1538512086000, churnInNext3Days=0),
#  Row(page='Add Friend', ts=1538512087000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538512286000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538512287000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538512433000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538512827000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538513224000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538513331000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538513581000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538513831000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538513832000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538514091000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538514342000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538514577000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538514828000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538515355000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538515356000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538515590000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538515785000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538516044000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538516470000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538516670000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538516896000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538517035000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538517261000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538517477000, churnInNext3Days=0),
#  Row(page='Home', ts=1538517546000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538517554000, churnInNext3Days=0),
#  Row(page='Home', ts=1538517567000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538517818000, churnInNext3Days=0),
#  Row(page='Logout', ts=1538517819000, churnInNext3Days=0),
#  Row(page='Home', ts=1538518184000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538518201000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538518412000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538518644000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538518840000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538519056000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538519320000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538519521000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538519888000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538520362000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538520658000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538520747000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538520878000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538521122000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538521130000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538521283000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538521541000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538521623000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538521839000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538522039000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538522221000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538522402000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538522669000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538522855000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538523055000, churnInNext3Days=0),
#  Row(page='Settings', ts=1538523319000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538523360000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538523361000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538548365000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538548859000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538549078000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538549296000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538549656000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538549851000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538549852000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538550227000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538550320000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538550569000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538550570000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538550785000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538550956000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538551183000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538551464000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538551677000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538551897000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538552221000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538552536000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538552767000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538553141000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538553462000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538553677000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538554058000, churnInNext3Days=0),
#  Row(page='Logout', ts=1538554059000, churnInNext3Days=0),
#  Row(page='Home', ts=1538554143000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538554317000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538554360000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538554505000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538554525000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538572176000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538572462000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538572728000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538572729000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538572917000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538573091000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538573296000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538573520000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538573727000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538573804000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538573977000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538574144000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538574355000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538574945000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538575180000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538575405000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538575618000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538575909000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538576129000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538576161000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538576280000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538576506000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538576768000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538577014000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538577322000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538577796000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538578066000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538578304000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538578528000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538578702000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538579145000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538579397000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538579603000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538579783000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538580012000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538580280000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538580546000, churnInNext3Days=0),
#  Row(page='Home', ts=1538580606000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538580775000, churnInNext3Days=0),
#  Row(page='Logout', ts=1538580776000, churnInNext3Days=0),
#  Row(page='Home', ts=1538580843000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538581020000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538581472000, churnInNext3Days=0),
#  Row(page='Thumbs Up', ts=1538581473000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538581730000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538581941000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538582130000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538582358000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538582402000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538582723000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538583595000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538583827000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538584047000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538584373000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538584593000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538584886000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538585377000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538585544000, churnInNext3Days=0),
#  Row(page='Home', ts=1538585623000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538585758000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538586034000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538586247000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538586442000, churnInNext3Days=0),
#  Row(page='Home', ts=1538586493000, churnInNext3Days=0),
#  Row(page='Add Friend', ts=1538586494000, churnInNext3Days=0),
#  Row(page='Add Friend', ts=1538586495000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538586601000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538586833000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538587017000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538587217000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538587432000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538587647000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538587958000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538588109000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538588535000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538588772000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538589098000, churnInNext3Days=0),
#  Row(page='Add to Playlist', ts=1538589110000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538589417000, churnInNext3Days=0),
#  Row(page='About', ts=1538589516000, churnInNext3Days=0),
#  Row(page='NextSong', ts=1538717270000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538717499000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538717738000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538717956000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538718224000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538718462000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538718839000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538719048000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538719467000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538719802000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538720095000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538720331000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538720613000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538721049000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538721304000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538721523000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538721783000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538722015000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538722239000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538722598000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538722781000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538723325000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538723544000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538723863000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538724128000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538724361000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538724529000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538724823000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538725064000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538725719000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538725969000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538726200000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538726452000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538726619000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538726976000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538727277000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538727518000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538727731000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538727940000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538728158000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538728377000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538728553000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538728757000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538728981000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538729280000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538729535000, churnInNext3Days=1),
#  Row(page='Logout', ts=1538729536000, churnInNext3Days=1),
#  Row(page='Home', ts=1538729862000, churnInNext3Days=1),
#  Row(page='Logout', ts=1538729863000, churnInNext3Days=1),
#  Row(page='Home', ts=1538729892000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538729959000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538730141000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538730293000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538730493000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538730745000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538730963000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538731141000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538731430000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538731677000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538732124000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538732346000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538732568000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538732828000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538733001000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538733166000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538733337000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538733556000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538733830000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538734029000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538734214000, churnInNext3Days=1),
#  Row(page='Add to Playlist', ts=1538734246000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538734489000, churnInNext3Days=1),
#  Row(page='Add to Playlist', ts=1538734493000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538734771000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538735040000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538735305000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538735464000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538735898000, churnInNext3Days=1),
#  Row(page='Add Friend', ts=1538735899000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538736248000, churnInNext3Days=1),
#  Row(page='Home', ts=1538736263000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538736485000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538736805000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538736985000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538737265000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538737503000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538737939000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538738177000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538738525000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538738705000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538738906000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538739280000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538739763000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538740477000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538740753000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538740953000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538741336000, churnInNext3Days=1),
#  Row(page='Add to Playlist', ts=1538741544000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538741589000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538741857000, churnInNext3Days=1),
#  Row(page='Add Friend', ts=1538741858000, churnInNext3Days=1),
#  Row(page='Add Friend', ts=1538741859000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538742162000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538742422000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538742717000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538742946000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538743156000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538743335000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538743555000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538743784000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538744032000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538744033000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538744384000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538744637000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538744914000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538745178000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538745466000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538745675000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538745964000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538746197000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538746412000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538746644000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538746954000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538747397000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538747633000, churnInNext3Days=1),
#  Row(page='Home', ts=1538747649000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538747913000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538748073000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538748313000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538748314000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538748502000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538748692000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538748842000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538749178000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538749322000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538749529000, churnInNext3Days=1),
#  Row(page='Downgrade', ts=1538749555000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538749728000, churnInNext3Days=1),
#  Row(page='Add Friend', ts=1538749729000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538749925000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538750136000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538750337000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538750541000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538750746000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538750965000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538750966000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538751219000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538751387000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538751623000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538751848000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538751849000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538752069000, churnInNext3Days=1),
#  Row(page='Add to Playlist', ts=1538752179000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538752264000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538752560000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538752741000, churnInNext3Days=1),
#  Row(page='Help', ts=1538752783000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538753015000, churnInNext3Days=1),
#  Row(page='Home', ts=1538753163000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538753168000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538753403000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538753614000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538753847000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538754155000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538754340000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538754469000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538754708000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538754709000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538755009000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538755165000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538755406000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538755699000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538755953000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538756188000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538756446000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538756649000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538756908000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538757214000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538757516000, churnInNext3Days=1),
#  Row(page='Home', ts=1538757526000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538923274000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538923542000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538923713000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538923714000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538923920000, churnInNext3Days=1),
#  Row(page='Add to Playlist', ts=1538923920000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538924164000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538924424000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538924683000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538924946000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538925240000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538925471000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538925616000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538925835000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538926112000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538926374000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538926532000, churnInNext3Days=1),
#  Row(page='Settings', ts=1538926551000, churnInNext3Days=1),
#  Row(page='Save Settings', ts=1538926552000, churnInNext3Days=1),
#  Row(page='Home', ts=1538926692000, churnInNext3Days=1),
#  Row(page='Add Friend', ts=1538926693000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538926767000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538926933000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538927141000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538927386000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538927635000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538927860000, churnInNext3Days=1),
#  Row(page='Add to Playlist', ts=1538927866000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538928140000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538928485000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538928680000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538928923000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538929155000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538929368000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538929542000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538929842000, churnInNext3Days=1),
#  Row(page='Thumbs Down', ts=1538929843000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538930128000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538930367000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538930560000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538930972000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538931191000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538931427000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538931784000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538932081000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538932385000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538932386000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538932962000, churnInNext3Days=1),
#  Row(page='Settings', ts=1538933022000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538933111000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538933271000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538933603000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538934035000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538934238000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538934522000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538934831000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538935042000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538935216000, churnInNext3Days=1),
#  Row(page='Downgrade', ts=1538935253000, churnInNext3Days=1),
#  Row(page='Logout', ts=1538935254000, churnInNext3Days=1),
#  Row(page='Home', ts=1538935378000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538935683000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538935875000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538935997000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538936263000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538936537000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538936770000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538937074000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538937268000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538937497000, churnInNext3Days=1),
#  Row(page='Home', ts=1538937553000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538937697000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538937891000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538938096000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538938452000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538938727000, churnInNext3Days=1),
#  Row(page='Add Friend', ts=1538938728000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538938966000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538939164000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538939386000, churnInNext3Days=1),
#  Row(page='Thumbs Up', ts=1538939387000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538939637000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538939856000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538939978000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538940231000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538940279000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538940518000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538940816000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538941085000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538941297000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538941482000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538941694000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538942030000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538942425000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538942663000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538942837000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538943117000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538943440000, churnInNext3Days=1),
#  Row(page='NextSong', ts=1538943726000, churnInNext3Days=1),
#  Row(page='Downgrade', ts=1538943739000, churnInNext3Days=1),
#  Row(page='Cancel', ts=1538943740000, churnInNext3Days=1),
#  Row(page='Cancellation Confirmation', ts=1538943990000, churnInNext3Days=1)]

# %%
train_Full, test_Full = user_log_joined.randomSplit([0.7, 0.3], seed=42)

# build, train, and test a Logistic Regression model

# in order to prevent overfitting, I choose a regularization paramter of zero
# I aslo set elasticNetParam to zero so penalties will not be combined when I introduce regParam = 0.1 in my Pipeline
lr_Full =  LogisticRegression(maxIter=10, regParam=0.0, elasticNetParam=0)

# build pipeline
lrPipeline_Full = Pipeline(stages=[lr_Full])

# add regParam value of 0.1 to be tested
lrParamGrid_Full = ParamGridBuilder() \
    .addGrid(lr_Full.regParam,[0.0, 0.1]) \
    .build()

# build CrossValidator with 3 folds
lrCrossval_Full = CrossValidator(estimator=lrPipeline_Full,
                          estimatorParamMaps=lrParamGrid_Full,
                          evaluator=BinaryClassificationEvaluator(),
                          numFolds=3)

# train model on Normalizer feature vector
lrModel1_Full = lrCrossval_Full.fit(train_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures").alias("features")))
# train model on StandardScaler feature vector
lrModel2_Full = lrCrossval_Full.fit(train_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures2").alias("features")))

# test both models
lrResults1_Full = lrModel1_Full.transform(test_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures").alias("features")))
lrResults2_Full = lrModel2_Full.transform(test_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures2").alias("features")))

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(lrModel1_Full.avgMetrics)
print(lrResults1_Full.filter(lrResults1_Full.label == lrResults1_Full.prediction).count())
print(lrResults1_Full.count())
# Out:
# [0.5755427961999795, 0.5776755285920987]
# 80846
# 83278

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(lrModel2_Full.avgMetrics)
print(lrResults2_Full.filter(lrResults2_Full.label == lrResults2_Full.prediction).count())
print(lrResults2_Full.count())
# Out:
# [0.9016220716172856, 0.894966678736054]
# 80841
# 83278

# %%
# build, train, and test a Random Forest model

rf_Full = RandomForestClassifier(featuresCol = 'features', labelCol = 'label')

# build pipeline
rfPipeline_Full = Pipeline(stages=[rf_Full])

# set values of both 3 and 10 to be tested for the number of trees to build before averaging the trees' predictions
# I choose two low values in order to spare processing burden. If 10 performs better than 3, I could try higher values.
rfParamGrid_Full = ParamGridBuilder() \
    .addGrid(rf_Full.numTrees, [10, 100]) \
    .build()

# build CrossValidator with 3 folds
rfCrossval_Full = CrossValidator(
    estimator=rfPipeline_Full,
    estimatorParamMaps=rfParamGrid_Full,
    evaluator=BinaryClassificationEvaluator(),
    numFolds=3)

# train model on Normalizer feature vector
rfModel1_Full = rfCrossval_Full.fit(train_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures").alias("features")))
# train model on StandardScaler feature vector
rfModel2_Full = rfCrossval_Full.fit(train_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures2").alias("features")))

# test both models
rfResults1_Full = rfModel1_Full.transform(test_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures").alias("features")))
rfResults2_Full = rfModel2_Full.transform(test_Full.select(col("churnInNext3Days").alias("label"), col("ScaledNumFeatures2").alias("features")))

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(rfModel1_Full.avgMetrics)
print(rfResults1_Full.filter(rfResults1_Full.label == rfResults1_Full.prediction).count())
print(rfResults1_Full.count())
# Out:
# [0.8538842208767887, 0.8637761254177923]
# 80892
# 83278

# %%
# view average metrics along with the count of correct predictions and total predictions
# see blog post for discussion
print(rfModel2_Full.avgMetrics)
print(rfResults2_Full.filter(rfResults2_Full.label == rfResults2_Full.prediction).count())
print(rfResults2_Full.count())
# Out:
# [0.9134377429780883, 0.9151635211010412]
# 80861
# 83278
